# %% [markdown]
# # 1. Downloading data from big query

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import db_dtypes
from plotly import tools
import chart_studio.plotly as py
import plotly.figure_factory as ff
import plotly.graph_objs as go
from google.cloud import bigquery
from google.oauth2 import service_account
import os

# %%
creds = service_account.Credentials.from_service_account_file("./purple-25-gradient-20250605-9a86eb7ca8de.json")
client = bigquery.Client(credentials=creds, project="purple-25-gradient-20250605")

# List of tables to download
tables = [
    # "purple-25-gradient-20250605.chicago_active_business_licenses.active_business_licenses",
    # "purple-25-gradient-20250605.chicago_demographics.population_counts",
    # "purple-25-gradient-20250605.chicago_food_inspections.food_inspections_data",
    # "purple-25-gradient-20250605.chicago_zoning.zoning_data",
    # "purple-25-gradient-20250605.divvy_stations.divvy_stations_data",
    # "purple-25-gradient-20250605.foot_traffic_chicago.yearly_average",
    "purple-25-gradient-20250605.cta_bus_stations.cta_bus_stations_data"

]

# Folder where you want to save CSVs
output_dir = "data_exports"

import os
os.makedirs(output_dir, exist_ok=True)

# Download each table as a CSV
for table_id in tables:
    print(f"Downloading {table_id}...")
    query = f"SELECT * FROM `{table_id}`"
    df = client.query(query).to_dataframe()
    
    # Save to CSV (file name from table name)
    table_name = table_id.split('.')[-1]
    output_path = os.path.join(output_dir, f"{table_name}.csv")
    df.to_csv(output_path, index=False)

    print(f"Saved to {output_path}")
# Out:
# Downloading purple-25-gradient-20250605.cta_bus_stations.cta_bus_stations_data...
# /Users/linda/Metrogrub/.venv/lib/python3.11/site-packages/google/cloud/bigquery/table.py:1957: UserWarning:
#
# BigQuery Storage module not found, fetch data with the REST endpoint instead.
# Saved to data_exports/cta_bus_stations_data.csv

# %% [markdown]
# ## Uploading table back into bigquery

# %%
from google.cloud import bigquery

# Define destination table: dataset_id.table_name (make in big query first)
table_id = "purple-25-gradient-20250605.chicago_active_business_licenses.business_licenses_v4_food_clean"

# Define the job config
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_TRUNCATE",  # Overwrites the table if it exists
    autodetect=True                      # Automatically detects schema from DataFrame
)

# Upload the DataFrame to BigQuery
job = client.load_table_from_dataframe(
    business_license_v4_food, table_id, job_config=job_config
)

# Wait for the job to complete
job.result()

print(f"✅ DataFrame uploaded to {table_id}")
# Out:
# /Users/linda/Metrogrub/metrogrub_project/data_cleaning/.venv/lib/python3.11/site-packages/google/cloud/bigquery/_pandas_helpers.py:489: FutureWarning:
#
# Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
# ✅ DataFrame uploaded to purple-25-gradient-20250605.chicago_active_business_licenses.business_licenses_v4_food_clean

# %%
import os
print(os.getcwd())
# Out:
# /Users/linda/Metrogrub/metrogrub_project/data_cleaning

# %%
# Loading Data
business_license = pd.read_csv(
    'data_exports/active_business_licenses.csv',
    dtype={'zip_code': str},  # force zip_code column to be string
    header='infer'
)

divvy_stations = pd.read_csv('data_exports/divvy_stations_data.csv', header='infer')
food_inspections = pd.read_csv('data_exports/food_inspections_data.csv', header='infer')
population_counts = pd.read_csv('data_exports/population_counts.csv', header='infer')
yearly_average = pd.read_csv('data_exports/yearly_average.csv', header='infer')
zoning_data = pd.read_csv('data_exports/zoning_data.csv', header='infer')
bus_data = pd.read_csv('data_exports/cta_bus_stations_data.csv', header='infer')
# zoning_data.head()

# %% [markdown]
# # 2. Perfoming EDA (Exploratory Data Analysis)

# %% [markdown]
# ## 2.1 Active Business Licenses

# %%
business_license.head()
# Out:
#                  id  license_id  account_number  site_number                          legal_name              doing_business_as_name                  address     city state zip_code  ward  precinct ward_precinct  police_district  community_area community_area_name           neighborhood  license_code            license_description business_activity_id                                                                                                              business_activity  license_number application_type application_requirements_complete               payment_date conditional_approval         license_start_date            expiration_date license_approved_for_issuance                date_issued license_status   latitude  longitude                                                                   location
# 0  3025375-20250502     3025375          463149            6                    LAO PENG YOU LLC                        LAO PENG YOU       2020 W CHICAGO AVE  CHICAGO    IL    60622  36.0      21.0         36-21             12.0            24.0           WEST TOWN      UKRAINIAN VILLAGE          1329             Special Event Food                946.0                                                                                   180 Day Multiple Events - Special Event Food         3025375            ISSUE         2025-04-16 00:00:00+00:00  2025-04-16 00:00:00+00:00                    N  2025-05-02 00:00:00+00:00  2025-10-27 00:00:00+00:00     2025-05-01 00:00:00+00:00  2025-05-02 00:00:00+00:00            AAI  41.896005 -87.677938  {"type": "Point", "coordinates": [-87.6779378973854, 41.896004699879654]}
# 1  3026047-20250501     3026047          516305            1                       MATTHEW APGAR                       MATTHEW APGAR   [REDACTED FOR PRIVACY]  CHICAGO    IL    60614   NaN      16.0           -16             19.0             7.0        LINCOLN PARK     SHEFFIELD & DEPAUL          7009  Pharmaceutical Representative                990.0  Markets / Promotes Pharmaceuticals to Health Care Professionals and Conducts Business for More than 15 Calendar Days per Year         3026047            ISSUE         2025-04-30 00:00:00+00:00  2025-04-30 00:00:00+00:00                    N  2025-05-01 00:00:00+00:00  2026-05-15 00:00:00+00:00     2025-04-30 00:00:00+00:00  2025-05-01 00:00:00+00:00            AAI   0.000000   0.000000                                                                        NaN
# 2  2615773-20250501     3013467          392036            1  CHICAGO PRIVATE YACHT RENTALS, INC  CHICAGO PRIVATE YACHT RENTALS, INC      6932 N DOWAGIAC AVE  CHICAGO    IL    60646  45.0       9.0          45-9             16.0            12.0         FOREST GLEN  SAUGANASH,FOREST GLEN          7020    Commercial Passenger Vessel               1012.0                                                             Operation of a Commercial Passenger Vessel - 20 or More Passengers         2615773            RENEW         2025-02-15 00:00:00+00:00  2025-03-19 00:00:00+00:00                    N  2025-05-01 00:00:00+00:00  2026-04-30 00:00:00+00:00     2025-04-30 00:00:00+00:00  2025-04-30 00:00:00+00:00            AAI  42.006666 -87.767159  {"type": "Point", "coordinates": [-87.76715933374193, 42.00666641852602]}
# 3  2615905-20250501     3025740          360866            1     CHICAGO SAILBOAT CHARTERS, INC.     CHICAGO SAILBOAT CHARTERS  INC.       13539 S FOREST AVE  CHICAGO    IL    60827  10.0      26.0         10-26              5.0            54.0           RIVERDALE              RIVERDALE          7020    Commercial Passenger Vessel               1011.0                                                               Operation of a Commercial Passenger Vessel - Under 20 Passengers         2615905            RENEW         2025-04-24 00:00:00+00:00  2025-04-28 00:00:00+00:00                    N  2025-05-01 00:00:00+00:00  2026-04-30 00:00:00+00:00     2025-04-29 00:00:00+00:00  2025-04-29 00:00:00+00:00            AAI  41.648779 -87.614742  {"type": "Point", "coordinates": [-87.61474160509368, 41.64877912429937]}
# 4  2738095-20250501     3014267          468358            1              JUST RIGHT BOATING LLC              JUST RIGHT BOATING LLC  1201 E MADISON PARK   1  CHICAGO    IL    60615   4.0      23.0          4-23              2.0            39.0             KENWOOD                KENWOOD          7020    Commercial Passenger Vessel               1011.0                                                               Operation of a Commercial Passenger Vessel - Under 20 Passengers         2738095            RENEW         2025-02-15 00:00:00+00:00  2025-03-03 00:00:00+00:00                    N  2025-05-01 00:00:00+00:00  2026-04-30 00:00:00+00:00     2025-04-04 00:00:00+00:00  2025-04-04 00:00:00+00:00            AAI  41.802935 -87.596642  {"type": "Point", "coordinates": [-87.59664183166099, 41.80293463173875]}

# %% [markdown]
# ### Cleaning & transformation

# %%
# Selecting necessary Columns
columns_to_keep = [
    'license_id',
    'doing_business_as_name',
    'legal_name',
    # 'business_activity_id',
    'license_description',
    'business_activity',
    'latitude',
    'longitude',
    'city',
    'state',
    'address',
    'zip_code',
    'location'
]

# Select only the desired columns
business_license_v2 = business_license[columns_to_keep]
# Remove rows with no location data, no zip code, no buziness_activity
business_license_v2 = business_license_v2[business_license_v2['location'].notna()]
business_license_v2 = business_license_v2[business_license_v2['zip_code'].notna()]
business_license_v2 = business_license_v2[business_license_v2['business_activity'].notna()]
# Replace redacted in address with NaN value
business_license_v2['address'] = business_license_v2['address'].replace(r'\[REDACTED.*\]', np.nan, regex=True)
# Remove businesses that are located outside of IL (check shows a lot of debt collection licenses)
business_license_v2 = business_license_v2[business_license_v2['state'] == 'IL']
# Drop State col after filtering 
business_license_v2 = business_license_v2.drop(columns=['state'])
# Filter for food
business_license_v2_food = business_license_v2[
    business_license_v2['license_description'].str.contains('food', case=False, na=False)
]
# Remove duplicates of same biz license_id (keep only first one)
business_license_v3_food = business_license_v2_food.drop_duplicates(subset='license_id', keep='first')

def categorize_food_place(row):
    desc = str(row['license_description']).lower()
    name = str(row['doing_business_as_name']).lower()
    activity = str(row.get('business_activity', '')).lower()

    # Direct license-based categorization
    if 'mobile food' in desc:
        return 'food_truck'
    elif 'shared kitchen' in desc:
        return 'shared_kitchen'
    elif 'wholesale' in desc:
        return 'wholesale'
    elif 'special event' in desc:
        return 'event_food'
    elif 'pop-up' in desc:
        return 'pop_up'
    elif 'seasonal lakefront' in desc:
        return 'lakefront'

    # Name-based categorization for Retail Food
    fast_food_keywords = ['mcdonald', 'burger king', 'kfc', 'wendy', 'popeyes', 'subway', 'chipotle', 'taco bell', 'pizza hut', 'dunkin','shake shack', 'jack in the box']
    fine_dining_keywords = ['steakhouse', 'grill', 'bistro', 'chophouse', 'prime', 'fine dining']
    cafe_keywords = ['coffee', 'cafe', 'espresso', 'tea']
    bar_keywords = ['bar', 'pub', 'tavern', 'lounge']

    if any(kw in name for kw in fast_food_keywords):
        return 'fast_food'
    elif any(kw in name for kw in fine_dining_keywords):
        return 'fine_dining'
    elif any(kw in name for kw in cafe_keywords):
        return 'cafe'
    elif any(kw in name for kw in bar_keywords):
        return 'bar'
    else:
        return 'restaurant'  # fallback for Retail Food
    
business_license_v4_food = business_license_v3_food.copy()
business_license_v4_food['food_category'] = business_license_v3_food.apply(categorize_food, axis=1)
business_license_v4_food.head()

business_license_v4_food.head(10)
# Out:
#     license_id doing_business_as_name              legal_name        license_description                                                                               business_activity   latitude  longitude     city                   address zip_code                                                                    location food_category
# 0      3025375           LAO PENG YOU        LAO PENG YOU LLC         Special Event Food                                                    180 Day Multiple Events - Special Event Food  41.896005 -87.677938  CHICAGO        2020 W CHICAGO AVE    60622   {"type": "Point", "coordinates": [-87.6779378973854, 41.896004699879654]}    event_food
# 7      3025642     CHILLS ITALIAN ICE         LEMONCHILLO LLC         Special Event Food                                                    180 Day Multiple Events - Special Event Food  41.903060 -87.678437  CHICAGO     2029 W DIVISION ST  1    60622  {"type": "Point", "coordinates": [-87.67843725836676, 41.903059772046284]}    event_food
# 8      3020896    TACO PROS/EGG HOLIC     1400 LAKE PARK INC.  Retail Food Establishment                                                Sale of Food Prepared Onsite Without Dining Area  41.809795 -87.592374  CHICAGO         1400 E 47TH DR  E    60653   {"type": "Point", "coordinates": [-87.59237386663331, 41.80979548271692]}    restaurant
# 9      3020976       SAM 95 FOOD INC.        SAM 95 FOOD INC.  Retail Food Establishment  Retail Sales of General Merchandise and Non-Perishable Food | Retail Sales of Perishable Foods  41.721357 -87.659962  CHICAGO        1452 W 95TH ST 1ST    60643   {"type": "Point", "coordinates": [-87.65996168027644, 41.72135685967372]}    restaurant
# 18     3020057        STALWART MARKET     STALWART MARKET LLC        Mobile Food License               Sales of Produce From a Produce Stand Located on an Urban Farm (Produce Merchant)  41.732108 -87.543374  CHICAGO       3320-3322 E 90TH ST    60617    {"type": "Point", "coordinates": [-87.5433735775229, 41.73210827910671]}    food_truck
# 20     3020668              BUST OUTS           BUST OUTS LLC         Special Event Food                                                    180 Day Multiple Events - Special Event Food  41.975258 -87.751991  CHICAGO         5200 N ELSTON AVE    60630   {"type": "Point", "coordinates": [-87.75199055715778, 41.97525809526954]}    event_food
# 21     3015553            JUST TURKEY         A&E FOODS, LTD.  Retail Food Establishment                                                Sale of Food Prepared Onsite Without Dining Area  41.815254 -87.606530  CHICAGO  4353 S COTTAGE GROVE AVE    60653   {"type": "Point", "coordinates": [-87.60653032909327, 41.81525376681689]}    restaurant
# 22     3020149              TACO PROS            JANU 17 INC.  Retail Food Establishment                                                Sale of Food Prepared Onsite Without Dining Area  41.736778 -87.587380  CHICAGO        1515 E 87TH ST 1ST    60619    {"type": "Point", "coordinates": [-87.58738032711261, 41.7367783273685]}    restaurant
# 23     3015912      FLOVAL BAKERY LLC       FLOVAL BAKERY LLC  Retail Food Establishment                                                Sale of Food Prepared Onsite Without Dining Area  41.785930 -87.734116  CHICAGO        4434 W 59TH ST 1ST    60629   {"type": "Point", "coordinates": [-87.73411585836406, 41.78593046631094]}    restaurant
# 25     3025599      MALDO LATIN GRILL  MALDO LATIN GRILL, LLC         Special Event Food                                                    180 Day Multiple Events - Special Event Food  41.738781 -87.588957  CHICAGO          8559 S DANTE AVE    60619  {"type": "Point", "coordinates": [-87.58895651350097, 41.738781230393094]}    event_food

# %%
business_license_v4_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11744 entries, 0 to 161467
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   license_id              11744 non-null  int64
#  1   doing_business_as_name  11744 non-null  object
#  2   legal_name              11744 non-null  object
#  3   license_description     11744 non-null  object
#  4   business_activity       11744 non-null  object
#  5   latitude                11744 non-null  float64
#  6   longitude               11744 non-null  float64
#  7   city                    11744 non-null  object
#  8   address                 11744 non-null  object
#  9   zip_code                11744 non-null  object
#  10  location                11744 non-null  object
#  11  food_category           11744 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 1.2+ MB

# %%
import missingno as msno
business_license.isnull().sum()                              # Count of nulls
msno.matrix(business_license_v3_food)                                # Visualize missing data
plt.show()

# %%
# Summary stats including object columns
business_license_v4_food.describe(include='all').T
# Out:
#                           count unique                                                                        top   freq            mean           std        min         25%        50%        75%        max
# license_id              11744.0    NaN                                                                        NaN    NaN  2968368.729819  36812.329299  2245772.0  2937574.75  2967221.0  3000487.5  3036139.0
# doing_business_as_name    11744   9731                                                                     SUBWAY    116             NaN           NaN        NaN         NaN        NaN        NaN        NaN
# legal_name                11744   9254                                                      STARBUCKS CORPORATION    125             NaN           NaN        NaN         NaN        NaN        NaN        NaN
# license_description       11744      8                                                  Retail Food Establishment  10956             NaN           NaN        NaN         NaN        NaN        NaN        NaN
# business_activity         11744    253                                           Retail Sales of Perishable Foods   4029             NaN           NaN        NaN         NaN        NaN        NaN        NaN
# latitude                11744.0    NaN                                                                        NaN    NaN       41.882679      0.077737   41.64467   41.840945  41.891794  41.939163  42.020808
# longitude               11744.0    NaN                                                                        NaN    NaN      -87.677823       0.05867 -87.906874  -87.708219 -87.667626 -87.636703 -87.525094
# city                      11744      3                                                                    CHICAGO  11742             NaN           NaN        NaN         NaN        NaN        NaN        NaN
# address                   11744  10919                                                           2300 S THROOP ST     86             NaN           NaN        NaN         NaN        NaN        NaN        NaN
# zip_code                  11744     61                                                                      60608    493             NaN           NaN        NaN         NaN        NaN        NaN        NaN
# location                  11744   9812  {"type": "Point", "coordinates": [-87.90687413400109, 42.00875076599798]}    167             NaN           NaN        NaN         NaN        NaN        NaN        NaN
# food_category             11744     11                                                                 restaurant   9128             NaN           NaN        NaN         NaN        NaN        NaN        NaN

# %%
# from skimpy import skim
# skim(business_license_v2_food)

# %% [markdown]
# ### Summary

# %%
from summarytools import dfSummary
dfSummary(business_license_v4_food)
# Out:
# <style type="text/css">
# #T_bb444 thead>tr>th {
#   text-align: left;
# }
# #T_bb444_row0_col0, #T_bb444_row1_col0, #T_bb444_row2_col0, #T_bb444_row3_col0, #T_bb444_row4_col0, #T_bb444_row5_col0, #T_bb444_row6_col0, #T_bb444_row7_col0, #T_bb444_row8_col0, #T_bb444_row9_col0, #T_bb444_row10_col0, #T_bb444_row11_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_bb444_row0_col1, #T_bb444_row1_col1, #T_bb444_row2_col1, #T_bb444_row3_col1, #T_bb444_row4_col1, #T_bb444_row5_col1, #T_bb444_row6_col1, #T_bb444_row7_col1, #T_bb444_row8_col1, #T_bb444_row9_col1, #T_bb444_row10_col1, #T_bb444_row11_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_bb444_row0_col2, #T_bb444_row1_col2, #T_bb444_row2_col2, #T_bb444_row3_col2, #T_bb444_row4_col2, #T_bb444_row5_col2, #T_bb444_row6_col2, #T_bb444_row7_col2, #T_bb444_row8_col2, #T_bb444_row9_col2, #T_bb444_row10_col2, #T_bb444_row11_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_bb444_row0_col3, #T_bb444_row1_col3, #T_bb444_row2_col3, #T_bb444_row3_col3, #T_bb444_row4_col3, #T_bb444_row5_col3, #T_bb444_row6_col3, #T_bb444_row7_col3, #T_bb444_row8_col3, #T_bb444_row9_col3, #T_bb444_row10_col3, #T_bb444_row11_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_bb444_row0_col4, #T_bb444_row1_col4, #T_bb444_row2_col4, #T_bb444_row3_col4, #T_bb444_row4_col4, #T_bb444_row5_col4, #T_bb444_row6_col4, #T_bb444_row7_col4, #T_bb444_row8_col4, #T_bb444_row9_col4, #T_bb444_row10_col4, #T_bb444_row11_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_bb444_row0_col5, #T_bb444_row1_col5, #T_bb444_row2_col5, #T_bb444_row3_col5, #T_bb444_row4_col5, #T_bb444_row5_col5, #T_bb444_row6_col5, #T_bb444_row7_col5, #T_bb444_row8_col5, #T_bb444_row9_col5, #T_bb444_row10_col5, #T_bb444_row11_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_bb444">
#   <caption><strong>Data Frame Summary</strong><br>business_license_v4_food<br>Dimensions: 11,744 x 12<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_bb444_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_bb444_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_bb444_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_bb444_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_bb444_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_bb444_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bb444_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_bb444_row0_col1" class="data row0 col1" ><strong>license_id</strong><br>[int64]</td>
#       <td id="T_bb444_row0_col2" class="data row0 col2" >Mean (sd) : 2968368.7 (36812.3)<br>min < med < max:<br>2245772.0 < 2967221.0 < 3036139.0<br>IQR (CV) : 62912.8 (80.6)</td>
#       <td id="T_bb444_row0_col3" class="data row0 col3" >11,744 distinct values</td>
#       <td id="T_bb444_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_bb444_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_bb444_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_bb444_row1_col1" class="data row1 col1" ><strong>doing_business_as_name</strong><br>[object]</td>
#       <td id="T_bb444_row1_col2" class="data row1 col2" >1. SUBWAY<br>2. DUNKIN DONUTS<br>3. CITGO<br>4. SHELL<br>5. BP<br>6. 7-ELEVEN<br>7. MCDONALD'S<br>8. Dunkin Donuts<br>9. MCDONALDS<br>10. WHOLE FOODS MARKET<br>11. other</td>
#       <td id="T_bb444_row1_col3" class="data row1 col3" >116 (1.0%)<br>95 (0.8%)<br>31 (0.3%)<br>29 (0.2%)<br>25 (0.2%)<br>25 (0.2%)<br>22 (0.2%)<br>21 (0.2%)<br>21 (0.2%)<br>18 (0.2%)<br>11,341 (96.6%)</td>
#       <td id="T_bb444_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_bb444_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_bb444_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_bb444_row2_col1" class="data row2 col1" ><strong>legal_name</strong><br>[object]</td>
#       <td id="T_bb444_row2_col2" class="data row2 col2" >1. STARBUCKS CORPORATION<br>2. FAMILY DOLLAR, LLC<br>3. WALGREEN CO.<br>4. COMPASS GROUP USA, INC.<br>5. HOST INTERNATIONAL, INC.<br>6. THE UNIVERSITY OF CHICAGO<br>7. BOND DRUG COMPANY OF ILLINOIS,<br>8. JEWEL FOOD STORES, INC.<br>9. QUEST FOOD MANAGEMENT SERVICES<br>10. POTBELLY SANDWICH WORKS, LLC<br>11. other</td>
#       <td id="T_bb444_row2_col3" class="data row2 col3" >125 (1.1%)<br>69 (0.6%)<br>64 (0.5%)<br>61 (0.5%)<br>49 (0.4%)<br>48 (0.4%)<br>46 (0.4%)<br>43 (0.4%)<br>41 (0.3%)<br>41 (0.3%)<br>11,157 (95.0%)</td>
#       <td id="T_bb444_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_bb444_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_bb444_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_bb444_row3_col1" class="data row3 col1" ><strong>license_description</strong><br>[object]</td>
#       <td id="T_bb444_row3_col2" class="data row3 col2" >1. Retail Food Establishment<br>2. Wholesale Food Establishment<br>3. Special Event Food<br>4. Mobile Food License<br>5. Food - Shared Kitchen - Supple<br>6. Food - Shared Kitchen<br>7. Retail Food - Seasonal Lakefro<br>8. Pop-Up Food Est. User - Tier I</td>
#       <td id="T_bb444_row3_col3" class="data row3 col3" >10,956 (93.3%)<br>388 (3.3%)<br>140 (1.2%)<br>137 (1.2%)<br>99 (0.8%)<br>21 (0.2%)<br>2 (0.0%)<br>1 (0.0%)</td>
#       <td id="T_bb444_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_bb444_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_bb444_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_bb444_row4_col1" class="data row4 col1" ><strong>business_activity</strong><br>[object]</td>
#       <td id="T_bb444_row4_col2" class="data row4 col2" >1. Retail Sales of Perishable Foo<br>2. Preparation of Food and Dining<br>3. Sale of Food Prepared Onsite W<br>4. Sale of Food Prepared Onsite W<br>5. Retail Sales of General Mercha<br>6. Enagage in Wholesale Food Sale<br>7. Sale of Food Prepared Onsite W<br>8. Preparation of Food and Dining<br>9. Operation of a Shared Kitchen <br>10. Preparation and Sale of Food (<br>11. other</td>
#       <td id="T_bb444_row4_col3" class="data row4 col3" >4,029 (34.3%)<br>2,308 (19.7%)<br>1,499 (12.8%)<br>866 (7.4%)<br>439 (3.7%)<br>260 (2.2%)<br>163 (1.4%)<br>112 (1.0%)<br>99 (0.8%)<br>91 (0.8%)<br>1,878 (16.0%)</td>
#       <td id="T_bb444_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_bb444_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_bb444_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_bb444_row5_col1" class="data row5 col1" ><strong>latitude</strong><br>[float64]</td>
#       <td id="T_bb444_row5_col2" class="data row5 col2" >Mean (sd) : 41.9 (0.1)<br>min < med < max:<br>41.6 < 41.9 < 42.0<br>IQR (CV) : 0.1 (538.8)</td>
#       <td id="T_bb444_row5_col3" class="data row5 col3" >9,812 distinct values</td>
#       <td id="T_bb444_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_bb444_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_bb444_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_bb444_row6_col1" class="data row6 col1" ><strong>longitude</strong><br>[float64]</td>
#       <td id="T_bb444_row6_col2" class="data row6 col2" >Mean (sd) : -87.7 (0.1)<br>min < med < max:<br>-87.9 < -87.7 < -87.5<br>IQR (CV) : 0.1 (-14

# %%
business_license_v2_food = business_license_v2[
    business_license_v2['license_description'].str.contains('food', case=False, na=False)
]
business_license_v2_food['license_description'].value_counts().reset_index().rename(columns={
    'index': 'license_description',
    'license_description': 'count'
}).head()

# pd.set_option('display.max_rows', None)    # Show all rows
# pd.set_option('display.max_colwidth', None)  # Prevent column value cutoff
# view
# Out:
#                                   count  count
# 0             Retail Food Establishment  33514
# 1          Wholesale Food Establishment   1199
# 2                    Special Event Food    520
# 3                   Mobile Food License    432
# 4  Food - Shared Kitchen - Supplemental    303

# %%
business_license_v2_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36042 entries, 0 to 161926
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   license_id              36042 non-null  int64
#  1   doing_business_as_name  36042 non-null  object
#  2   legal_name              36042 non-null  object
#  3   license_description     36042 non-null  object
#  4   business_activity       36039 non-null  object
#  5   latitude                36042 non-null  float64
#  6   longitude               36042 non-null  float64
#  7   city                    36042 non-null  object
#  8   state                   36042 non-null  object
#  9   address                 36042 non-null  object
#  10  zip_code                36009 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# ### License_types categorization

# %%
view = business_license_v3_food['license_description'].value_counts(dropna=False).reset_index().rename(columns={
    'index': 'business_activity',
    'license_description': 'license_description'
})
view
# Out:
#                                    license_description  count
# 0                            Retail Food Establishment  10956
# 1                         Wholesale Food Establishment    388
# 2                                   Special Event Food    140
# 3                                  Mobile Food License    137
# 4                 Food - Shared Kitchen - Supplemental     99
# 5                                Food - Shared Kitchen     21
# 6  Retail Food - Seasonal Lakefront Food Establishment      2
# 7                       Pop-Up Food Est. User - Tier I      1

# %%
def categorize_food_place(row):
    desc = str(row['license_description']).lower()
    name = str(row['doing_business_as_name']).lower()
    activity = str(row.get('business_activity', '')).lower()

    # Direct license-based categorization
    if 'mobile food' in desc:
        return 'food_truck'
    elif 'shared kitchen' in desc:
        return 'shared_kitchen'
    elif 'wholesale' in desc:
        return 'wholesale'
    elif 'special event' in desc:
        return 'event_food'
    elif 'pop-up' in desc:
        return 'pop_up'
    elif 'seasonal lakefront' in desc:
        return 'lakefront'

    # Name-based categorization for Retail Food
    fast_food_keywords = ['mcdonald', 'burger king', 'kfc', 'wendy', 'popeyes', 'subway', 'chipotle', 'taco bell', 'pizza hut', 'dunkin','shake shack', 'jack in the box']
    fine_dining_keywords = ['steakhouse', 'grill', 'bistro', 'chophouse', 'prime', 'fine dining']
    cafe_keywords = ['coffee', 'cafe', 'espresso', 'tea']
    bar_keywords = ['bar', 'pub', 'tavern', 'lounge']

    if any(kw in name for kw in fast_food_keywords):
        return 'fast_food'
    elif any(kw in name for kw in fine_dining_keywords):
        return 'fine_dining'
    elif any(kw in name for kw in cafe_keywords):
        return 'cafe'
    elif any(kw in name for kw in bar_keywords):
        return 'bar'
    else:
        return 'restaurant'  # fallback for Retail Food

# %%
def categorize_food_place(row):
    desc = str(row['license_description']).lower()
    name_dba = str(row.get('doing_business_as_name', '')).lower()
    name_legal = str(row.get('legal_name', '')).lower()
    activity = str(row.get('business_activity', '')).lower()

    # Direct license-based categorization
    if 'mobile food' in desc:
        return 'food_truck'
    elif 'shared kitchen' in desc:
        return 'shared_kitchen'
    elif 'wholesale' in desc:
        return 'wholesale'
    elif 'special event' in desc:
        return 'event_food'
    elif 'pop-up' in desc:
        return 'pop_up'
    elif 'seasonal lakefront' in desc:
        return 'lakefront'

    # Business activity-based categorization
    if 'retail sales of general merchandise' in activity:
        return 'convenience_store'
    elif 'administrative commercial office' in activity:
        return 'office_cafeteria'

    # Combined name-based categorization
    full_name = f"{name_dba} {name_legal}"

    fast_food_keywords = [
        'raising cane', '7-eleven', 'pizza hut', 'wingstop', 'jimmy johns', 'dunkin',
        'potbelly', 'chick-fil-a', 'dominos', 'mcdonald', 'kentucky', 'kfc',
        'shake shack', 'burger king', 'taco bell', 'subway', 'wendy', 'popeyes'
    ]
    fine_dining_keywords = ['steakhouse', 'grill', 'bistro', 'chophouse', 'prime', 'fine dining']
    cafe_keywords = ['coffee', 'cafe', 'espresso', 'tea']
    bar_keywords = ['bar', 'pub', 'tavern', 'lounge']

    if any(kw in full_name for kw in fast_food_keywords):
        return 'fast_food'
    elif any(kw in full_name for kw in fine_dining_keywords):
        return 'fine_dining'
    elif any(kw in full_name for kw in cafe_keywords):
        return 'cafe'
    elif any(kw in full_name for kw in bar_keywords):
        return 'bar'
    else:
        return 'restaurant'  # fallback

# %%
restaurants = business_license_v3_food.copy()
restaurants['food_category'] = business_license_v3_food.apply(categorize_food_place, axis=1)
restaurants.head()
# Out:
#     license_id doing_business_as_name           legal_name        license_description                                                                               business_activity   latitude  longitude     city                address zip_code                                                                    location      food_category
# 0      3025375           LAO PENG YOU     LAO PENG YOU LLC         Special Event Food                                                    180 Day Multiple Events - Special Event Food  41.896005 -87.677938  CHICAGO     2020 W CHICAGO AVE    60622   {"type": "Point", "coordinates": [-87.6779378973854, 41.896004699879654]}         event_food
# 7      3025642     CHILLS ITALIAN ICE      LEMONCHILLO LLC         Special Event Food                                                    180 Day Multiple Events - Special Event Food  41.903060 -87.678437  CHICAGO  2029 W DIVISION ST  1    60622  {"type": "Point", "coordinates": [-87.67843725836676, 41.903059772046284]}         event_food
# 8      3020896    TACO PROS/EGG HOLIC  1400 LAKE PARK INC.  Retail Food Establishment                                                Sale of Food Prepared Onsite Without Dining Area  41.809795 -87.592374  CHICAGO      1400 E 47TH DR  E    60653   {"type": "Point", "coordinates": [-87.59237386663331, 41.80979548271692]}         restaurant
# 9      3020976       SAM 95 FOOD INC.     SAM 95 FOOD INC.  Retail Food Establishment  Retail Sales of General Merchandise and Non-Perishable Food | Retail Sales of Perishable Foods  41.721357 -87.659962  CHICAGO     1452 W 95TH ST 1ST    60643   {"type": "Point", "coordinates": [-87.65996168027644, 41.72135685967372]}  convenience_store
# 18     3020057        STALWART MARKET  STALWART MARKET LLC        Mobile Food License               Sales of Produce From a Produce Stand Located on an Urban Farm (Produce Merchant)  41.732108 -87.543374  CHICAGO    3320-3322 E 90TH ST    60617    {"type": "Point", "coordinates": [-87.5433735775229, 41.73210827910671]}         food_truck

# %%
restaurants['food_category'].value_counts()
# Out:
# food_category
# restaurant           7190
# convenience_store    1440
# fast_food             765
# cafe                  739
# bar                   459
# wholesale             388
# fine_dining           355
# event_food            140
# food_truck            137
# shared_kitchen        120
# office_cafeteria        8
# lakefront               2
# pop_up                  1
# Name: count, dtype: int64

# %% [markdown]
# #### Fast food check

# %%
fast_food_df = restaurants[restaurants['food_category']=='fast_food']
fast_food_df.head()
# Out:
#      license_id                     doing_business_as_name                      legal_name        license_description                                        business_activity   latitude  longitude     city             address zip_code                                                                    location food_category
# 77      3014102  JUBILEE COFFEE, INC. / DBA DUNKIN' DONUTS            JUBILEE COFFEE, INC.  Retail Food Establishment            Sale of Food Prepared Onsite With Dining Area  41.997598 -87.808253  CHICAGO    7240 W DEVON AVE    60631   {"type": "Point", "coordinates": [-87.80825275768383, 41.99759825874489]}     fast_food
# 187     3012775               Dunkin Donuts Baskin Robbins               DIVERSEY DBT INC.  Retail Food Establishment             Preparation and Sale of Coffee and/or Drinks  41.931757 -87.649125  CHICAGO   2706 N HALSTED ST    60614  {"type": "Point", "coordinates": [-87.64912468818162, 41.931757070122984]}     fast_food
# 278     3009271                           Burger King #142  TRI CITY FOODS OF ILLINOIS LLC  Retail Food Establishment            Sale of Food Prepared Onsite With Dining Area  41.794274 -87.723043  CHICAGO   5425 S PULASKI RD    60632   {"type": "Point", "coordinates": [-87.72304339449933, 41.79427426174653]}     fast_food
# 287     3009245                          BURGER KING #1512  TRI CITY FOODS OF ILLINOIS LLC  Retail Food Establishment  Preparation of Food and Dining on Premises With Seating  41.895863 -87.686192  CHICAGO  2344 W CHICAGO AVE    60622     {"type": "Point", "coordinates": [-87.68619201224591, 41.895863316453]}     fast_food
# 300     3009272                          Burger King #1338  TRI CITY FOODS OF ILLINOIS LLC  Retail Food Establishment            Sale of Food Prepared Onsite With Dining Area  41.692733 -87.701014  CHICAGO  11020 S KEDZIE AVE    60655  {"type": "Point", "coordinates": [-87.70101405389028, 41.692732531294446]}     fast_food

# %%
dfSummary(fast_food_df)
# Out:
# <style type="text/css">
# #T_0efc5 thead>tr>th {
#   text-align: left;
# }
# #T_0efc5_row0_col0, #T_0efc5_row1_col0, #T_0efc5_row2_col0, #T_0efc5_row3_col0, #T_0efc5_row4_col0, #T_0efc5_row5_col0, #T_0efc5_row6_col0, #T_0efc5_row7_col0, #T_0efc5_row8_col0, #T_0efc5_row9_col0, #T_0efc5_row10_col0, #T_0efc5_row11_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_0efc5_row0_col1, #T_0efc5_row1_col1, #T_0efc5_row2_col1, #T_0efc5_row3_col1, #T_0efc5_row4_col1, #T_0efc5_row5_col1, #T_0efc5_row6_col1, #T_0efc5_row7_col1, #T_0efc5_row8_col1, #T_0efc5_row9_col1, #T_0efc5_row10_col1, #T_0efc5_row11_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_0efc5_row0_col2, #T_0efc5_row1_col2, #T_0efc5_row2_col2, #T_0efc5_row3_col2, #T_0efc5_row4_col2, #T_0efc5_row5_col2, #T_0efc5_row6_col2, #T_0efc5_row7_col2, #T_0efc5_row8_col2, #T_0efc5_row9_col2, #T_0efc5_row10_col2, #T_0efc5_row11_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_0efc5_row0_col3, #T_0efc5_row1_col3, #T_0efc5_row2_col3, #T_0efc5_row3_col3, #T_0efc5_row4_col3, #T_0efc5_row5_col3, #T_0efc5_row6_col3, #T_0efc5_row7_col3, #T_0efc5_row8_col3, #T_0efc5_row9_col3, #T_0efc5_row10_col3, #T_0efc5_row11_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_0efc5_row0_col4, #T_0efc5_row1_col4, #T_0efc5_row2_col4, #T_0efc5_row3_col4, #T_0efc5_row4_col4, #T_0efc5_row5_col4, #T_0efc5_row6_col4, #T_0efc5_row7_col4, #T_0efc5_row8_col4, #T_0efc5_row9_col4, #T_0efc5_row10_col4, #T_0efc5_row11_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_0efc5_row0_col5, #T_0efc5_row1_col5, #T_0efc5_row2_col5, #T_0efc5_row3_col5, #T_0efc5_row4_col5, #T_0efc5_row5_col5, #T_0efc5_row6_col5, #T_0efc5_row7_col5, #T_0efc5_row8_col5, #T_0efc5_row9_col5, #T_0efc5_row10_col5, #T_0efc5_row11_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_0efc5">
#   <caption><strong>Data Frame Summary</strong><br>fast_food_df<br>Dimensions: 410 x 12<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_0efc5_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_0efc5_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_0efc5_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_0efc5_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_0efc5_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_0efc5_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0efc5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0efc5_row0_col1" class="data row0 col1" ><strong>license_id</strong><br>[int64]</td>
#       <td id="T_0efc5_row0_col2" class="data row0 col2" >Mean (sd) : 2971449.4 (37667.9)<br>min < med < max:<br>2868083.0 < 2969579.5 < 3033583.0<br>IQR (CV) : 72100.5 (78.9)</td>
#       <td id="T_0efc5_row0_col3" class="data row0 col3" >410 distinct values</td>
#       <td id="T_0efc5_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_0efc5_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_0efc5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_0efc5_row1_col1" class="data row1 col1" ><strong>doing_business_as_name</strong><br>[object]</td>
#       <td id="T_0efc5_row1_col2" class="data row1 col2" >1. SUBWAY<br>2. MCDONALD'S<br>3. MCDONALDS<br>4. Taco Bell<br>5. WENDY'S PROPERTIES, LLC<br>6. CHIPOTLE MEXICAN GRILL<br>7. McDONALD'S<br>8. KFC<br>9. TACO BELL<br>10. Chipotle Mexican Grill<br>11. other</td>
#       <td id="T_0efc5_row1_col3" class="data row1 col3" >116 (28.3%)<br>22 (5.4%)<br>21 (5.1%)<br>16 (3.9%)<br>15 (3.7%)<br>13 (3.2%)<br>12 (2.9%)<br>7 (1.7%)<br>7 (1.7%)<br>7 (1.7%)<br>174 (42.4%)</td>
#       <td id="T_0efc5_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_0efc5_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_0efc5_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_0efc5_row2_col1" class="data row2 col1" ><strong>legal_name</strong><br>[object]</td>
#       <td id="T_0efc5_row2_col2" class="data row2 col2" >1. CHIPOTLE MEXICAN GRILL, INC.<br>2. TRI CITY FOODS OF ILLINOIS LLC<br>3. WENDY'S PROPERTIES, LLC<br>4. AG BELLS II LLC<br>5. PEPINO/ROBLES LTD.<br>6. FAZAL DEVELOPMENT NETWORK INC<br>7. MCDONALD'S RESTAURANTS OF ILLI<br>8. RMS MANGEMENT, INC.<br>9. OMAKIN RESTAURANTS LLC<br>10. BUENA VIDA, LLC<br>11. other</td>
#       <td id="T_0efc5_row2_col3" class="data row2 col3" >34 (8.3%)<br>32 (7.8%)<br>21 (5.1%)<br>18 (4.4%)<br>10 (2.4%)<br>8 (2.0%)<br>7 (1.7%)<br>7 (1.7%)<br>7 (1.7%)<br>6 (1.5%)<br>260 (63.4%)</td>
#       <td id="T_0efc5_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_0efc5_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_0efc5_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_0efc5_row3_col1" class="data row3 col1" ><strong>license_description</strong><br>[object]</td>
#       <td id="T_0efc5_row3_col2" class="data row3 col2" >1. Retail Food Establishment</td>
#       <td id="T_0efc5_row3_col3" class="data row3 col3" >410 (100.0%)</td>
#       <td id="T_0efc5_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_0efc5_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_0efc5_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_0efc5_row4_col1" class="data row4 col1" ><strong>business_activity</strong><br>[object]</td>
#       <td id="T_0efc5_row4_col2" class="data row4 col2" >1. Retail Sales of Perishable Foo<br>2. Sale of Food Prepared Onsite W<br>3. Preparation of Food and Dining<br>4. Sale of Food Prepared Onsite W<br>5. Sale of Food Prepared Onsite W<br>6. Expedited Restaurant with On-P<br>7. Preparation of Food and Dining<br>8. Expedited Restaurant without O<br>9. Preparation of Food and Dining<br>10. Sale of Food Prepared Onsite W<br>11. other</td>
#       <td id="T_0efc5_row4_col3" class="data row4 col3" >138 (33.7%)<br>129 (31.5%)<br>100 (24.4%)<br>13 (3.2%)<br>8 (2.0%)<br>8 (2.0%)<br>7 (1.7%)<br>3 (0.7%)<br>1 (0.2%)<br>1 (0.2%)<br>2 (0.5%)</td>
#       <td id="T_0efc5_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_0efc5_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_0efc5_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_0efc5_row5_col1" class="data row5 col1" ><strong>latitude</strong><br>[float64]</td>
#       <td id="T_0efc5_row5_col2" class="data row5 col2" >Mean (sd) : 41.9 (0.1)<br>min < med < max:<br>41.6 < 41.9 < 42.0<br>IQR (CV) : 0.1 (470.9)</td>
#       <td id="T_0efc5_row5_col3" class="data row5 col3" >386 distinct values</td>
#       <td id="T_0efc5_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_0efc5_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_0efc5_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_0efc5_row6_col1" class="data row6 col1" ><strong>longitude</strong><br>[float64]</td>
#       <td id="T_0efc5_row6_col2" class="data row6 col2" >Mean (sd) : -87.7 (0.1)<br>min < med < max:<br>-87.9 < -87.7 < -87.5<br>IQR (CV) : 0.1 (-1373.8)</td>
#       <td id="T_0efc5_row6_col3" class="data row6 col3" >386 distinct values</td>
#       <td id="T_0efc5_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_0efc5_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_0efc5_row7_col0" class="data row7 col0" >8</td>
#       <

# %%
fast_food_df_sorted = fast_food_df.sort_values(by='doing_business_as_name', ascending=False)
fast_food_df_sorted.head()
# Out:
#         license_id doing_business_as_name                  legal_name        license_description                                                                             business_activity   latitude  longitude     city                      address zip_code                                                                   location food_category
# 35482      2931985                 subway  Niki & Japi Inc DBA Subway  Retail Food Establishment                                                              Retail Sales of Perishable Foods  41.908178 -87.746215  CHICAGO        1510 N CICERO AVE 1ST    60651  {"type": "Point", "coordinates": [-87.74621519474273, 41.90817759983461]}     fast_food
# 138228     2994926                 subway           RADHA FOODS, INC.  Retail Food Establishment                                                              Retail Sales of Perishable Foods  41.772725 -87.586442  CHICAGO  6718 S STONY ISLAND AVE 1ST    60649  {"type": "Point", "coordinates": [-87.58644243639392, 41.77272515346843]}     fast_food
# 147861     2961813                 subway  herndz food II corporation  Retail Food Establishment  Sale of Food Prepared Onsite With Dining Area | Preparation and Sale of Coffee and/or Drinks  41.877815 -87.642677  CHICAGO        304 S JEFFERSON ST  A    60661  {"type": "Point", "coordinates": [-87.64267682739994, 41.87781496811959]}     fast_food
# 40320      2991117               Wingstop            S & L Wings, LLC  Retail Food Establishment                                       Preparation of Food and Dining on Premises With Seating  41.936235 -87.766564  CHICAGO           3046 N CENTRAL AVE    60634  {"type": "Point", "coordinates": [-87.76656405018639, 41.93623461145712]}     fast_food
# 32779      2922445               Wingstop                CWK 79th LLC  Retail Food Establishment                                       Preparation of Food and Dining on Premises With Seating  41.748036 -87.741157  CHICAGO       7953 S CICERO AVE  D54    60652  {"type": "Point", "coordinates": [-87.74115697298679, 41.74803596790578]}     fast_food

# %% [markdown]
# ### other restaurants check

# %%
# other_df = restaurants[restaurants['food_category']=='restaurant']
other_df = restaurants[restaurants['food_category']=='convenience_store']
other_df.head()
# Out:
#      license_id doing_business_as_name                      legal_name        license_description                                                                                                                                                                                                    business_activity   latitude  longitude     city                   address zip_code                                                                    location      food_category
# 9       3020976       SAM 95 FOOD INC.                SAM 95 FOOD INC.  Retail Food Establishment                                                                                                                       Retail Sales of General Merchandise and Non-Perishable Food | Retail Sales of Perishable Foods  41.721357 -87.659962  CHICAGO        1452 W 95TH ST 1ST    60643   {"type": "Point", "coordinates": [-87.65996168027644, 41.72135685967372]}  convenience_store
# 33      3020522      WHOLE SALE MARKET  WHOLE SALE MARKET INCORPORATED  Retail Food Establishment  Retail Sales of Fresh Fruits and Vegetables (Leafy and Non Leafy Vegetables) | Retail Sales of General Merchandise and Non-Perishable Food | Retail Sales of Perishable Foods | Retail Sales of General Merchandise  41.778800 -87.605748  CHICAGO  6355 S COTTAGE GROVE AVE    60637   {"type": "Point", "coordinates": [-87.60574800239888, 41.77879981236933]}  convenience_store
# 117     3014069         REGENTS MARKET             SHUBHAM CORPORATION  Retail Food Establishment                                                                                                                       Retail Sales of General Merchandise and Non-Perishable Food | Retail Sales of Perishable Foods  41.802630 -87.584472  CHICAGO   1644 E HYDE PARK BLVD 1    60615  {"type": "Point", "coordinates": [-87.58447171338366, 41.802630048269855]}  convenience_store
# 125     3014295       All Day Kitchens                VRAIS FOODS, LLC  Retail Food Establishment                                                        Retail Sales of General Merchandise and Non-Perishable Food | Sale of Food Prepared Onsite Without Dining Area | Preparation and Sale of Coffee and/or Drinks  41.897956 -87.676964  CHICAGO      907 N DAMEN AVE  101    60622   {"type": "Point", "coordinates": [-87.67696390590685, 41.89795569189251]}  convenience_store
# 175     3014868               TWINSPOT                   TWINSPOT INC.  Retail Food Establishment                                                                               Preparation of Food, Coffee or Drinks | Retail Sales of General Merchandise and Non-Perishable Food | Retail Sales of Perishable Foods  41.780162 -87.613805  CHICAGO         447 E 63RD ST 1ST    60637   {"type": "Point", "coordinates": [-87.61380513050851, 41.78016157649594]}  convenience_store

# %%
dfSummary(other_df)
# Out:
# <style type="text/css">
# #T_f8a21 thead>tr>th {
#   text-align: left;
# }
# #T_f8a21_row0_col0, #T_f8a21_row1_col0, #T_f8a21_row2_col0, #T_f8a21_row3_col0, #T_f8a21_row4_col0, #T_f8a21_row5_col0, #T_f8a21_row6_col0, #T_f8a21_row7_col0, #T_f8a21_row8_col0, #T_f8a21_row9_col0, #T_f8a21_row10_col0, #T_f8a21_row11_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_f8a21_row0_col1, #T_f8a21_row1_col1, #T_f8a21_row2_col1, #T_f8a21_row3_col1, #T_f8a21_row4_col1, #T_f8a21_row5_col1, #T_f8a21_row6_col1, #T_f8a21_row7_col1, #T_f8a21_row8_col1, #T_f8a21_row9_col1, #T_f8a21_row10_col1, #T_f8a21_row11_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_f8a21_row0_col2, #T_f8a21_row1_col2, #T_f8a21_row2_col2, #T_f8a21_row3_col2, #T_f8a21_row4_col2, #T_f8a21_row5_col2, #T_f8a21_row6_col2, #T_f8a21_row7_col2, #T_f8a21_row8_col2, #T_f8a21_row9_col2, #T_f8a21_row10_col2, #T_f8a21_row11_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_f8a21_row0_col3, #T_f8a21_row1_col3, #T_f8a21_row2_col3, #T_f8a21_row3_col3, #T_f8a21_row4_col3, #T_f8a21_row5_col3, #T_f8a21_row6_col3, #T_f8a21_row7_col3, #T_f8a21_row8_col3, #T_f8a21_row9_col3, #T_f8a21_row10_col3, #T_f8a21_row11_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_f8a21_row0_col4, #T_f8a21_row1_col4, #T_f8a21_row2_col4, #T_f8a21_row3_col4, #T_f8a21_row4_col4, #T_f8a21_row5_col4, #T_f8a21_row6_col4, #T_f8a21_row7_col4, #T_f8a21_row8_col4, #T_f8a21_row9_col4, #T_f8a21_row10_col4, #T_f8a21_row11_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_f8a21_row0_col5, #T_f8a21_row1_col5, #T_f8a21_row2_col5, #T_f8a21_row3_col5, #T_f8a21_row4_col5, #T_f8a21_row5_col5, #T_f8a21_row6_col5, #T_f8a21_row7_col5, #T_f8a21_row8_col5, #T_f8a21_row9_col5, #T_f8a21_row10_col5, #T_f8a21_row11_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_f8a21">
#   <caption><strong>Data Frame Summary</strong><br>other_df<br>Dimensions: 1,440 x 12<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_f8a21_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_f8a21_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_f8a21_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_f8a21_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_f8a21_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_f8a21_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f8a21_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f8a21_row0_col1" class="data row0 col1" ><strong>license_id</strong><br>[int64]</td>
#       <td id="T_f8a21_row0_col2" class="data row0 col2" >Mean (sd) : 2968274.1 (35704.2)<br>min < med < max:<br>2836066.0 < 2966893.0 < 3035375.0<br>IQR (CV) : 59818.2 (83.1)</td>
#       <td id="T_f8a21_row0_col3" class="data row0 col3" >1,440 distinct values</td>
#       <td id="T_f8a21_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_f8a21_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f8a21_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_f8a21_row1_col1" class="data row1 col1" ><strong>doing_business_as_name</strong><br>[object]</td>
#       <td id="T_f8a21_row1_col2" class="data row1 col2" >1. BP<br>2. HUDSON NEWS<br>3. CITGO<br>4. Circle K<br>5. SHELL<br>6. SAVE A LOT<br>7. WHOLE FOODS MARKET<br>8. AMAZON GO<br>9. MOBIL<br>10. FALCON FUEL<br>11. other</td>
#       <td id="T_f8a21_row1_col3" class="data row1 col3" >14 (1.0%)<br>12 (0.8%)<br>12 (0.8%)<br>9 (0.6%)<br>7 (0.5%)<br>6 (0.4%)<br>6 (0.4%)<br>4 (0.3%)<br>4 (0.3%)<br>4 (0.3%)<br>1,362 (94.6%)</td>
#       <td id="T_f8a21_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_f8a21_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f8a21_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_f8a21_row2_col1" class="data row2 col1" ><strong>legal_name</strong><br>[object]</td>
#       <td id="T_f8a21_row2_col2" class="data row2 col2" >1. FAMILY DOLLAR, LLC<br>2. HUDSON NEWS O'HARE JOINT VENTU<br>3. DG RETAIL, LLC<br>4. TARGET CORPORATION<br>5. RDK VENTURES LLC<br>6. YELLOW BANANA ILLINOIS LLC<br>7. WALGREEN CO.<br>8. WHOLE FOODS MARKET GROUP, INC.<br>9. AMAZON RETAIL LLC<br>10. HIGHLAND PARK CVS, L.L.C.<br>11. other</td>
#       <td id="T_f8a21_row2_col3" class="data row2 col3" >21 (1.5%)<br>17 (1.2%)<br>15 (1.0%)<br>13 (0.9%)<br>13 (0.9%)<br>8 (0.6%)<br>8 (0.6%)<br>6 (0.4%)<br>5 (0.3%)<br>5 (0.3%)<br>1,329 (92.3%)</td>
#       <td id="T_f8a21_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_f8a21_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f8a21_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_f8a21_row3_col1" class="data row3 col1" ><strong>license_description</strong><br>[object]</td>
#       <td id="T_f8a21_row3_col2" class="data row3 col2" >1. Retail Food Establishment</td>
#       <td id="T_f8a21_row3_col3" class="data row3 col3" >1,440 (100.0%)</td>
#       <td id="T_f8a21_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_f8a21_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f8a21_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_f8a21_row4_col1" class="data row4 col1" ><strong>business_activity</strong><br>[object]</td>
#       <td id="T_f8a21_row4_col2" class="data row4 col2" >1. Retail Sales of General Mercha<br>2. Preparation of Food and Dining<br>3. Preparation of Food, Coffee or<br>4. Retail Sales of General Mercha<br>5. Retail Sales of General Mercha<br>6. Retail Sales of Perishable Foo<br>7. Preparation of Food, Coffee or<br>8. Retail Sales of General Mercha<br>9. Preparation of Food, Coffee or<br>10. Retail Sales of General Mercha<br>11. other</td>
#       <td id="T_f8a21_row4_col3" class="data row4 col3" >439 (30.5%)<br>112 (7.8%)<br>89 (6.2%)<br>81 (5.6%)<br>65 (4.5%)<br>59 (4.1%)<br>44 (3.1%)<br>41 (2.8%)<br>39 (2.7%)<br>38 (2.6%)<br>433 (30.1%)</td>
#       <td id="T_f8a21_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_f8a21_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f8a21_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_f8a21_row5_col1" class="data row5 col1" ><strong>latitude</strong><br>[float64]</td>
#       <td id="T_f8a21_row5_col2" class="data row5 col2" >Mean (sd) : 41.9 (0.1)<br>min < med < max:<br>41.7 < 41.9 < 42.0<br>IQR (CV) : 0.1 (495.7)</td>
#       <td id="T_f8a21_row5_col3" class="data row5 col3" >1,335 distinct values</td>
#       <td id="T_f8a21_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_f8a21_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f8a21_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_f8a21_row6_col1" class="data row6 col1" ><strong>longitude</strong><br>[float64]</td>
#       <td id="T_f8a21_row6_col2" class="data row6 col2" >Mean (sd) : -87.7 (0.1)<br>min < med < max:<br>-87.9 < -87.7 < -87.5<br>IQR (CV) : 0.1 (-1407.7)</td>
#       <td id="T_f8a21_row6_col3" class="data row6 col3" >1,335 distinct values</td>
#       <td id="T_f8a21_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_f8a21_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f8a21_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_f8a21_row7_col1" class="data row7 col1" ><s

# %%
type_view = restaurants.groupby(['license_description', 'food_category']).size().reset_index(name='count')
type_view.head()
# Out:
#                                    license_description   food_category  count
# 0                                Food - Shared Kitchen  shared_kitchen     21
# 1                 Food - Shared Kitchen - Supplemental  shared_kitchen     99
# 2                                  Mobile Food License      food_truck    137
# 3                       Pop-Up Food Est. User - Tier I          pop_up      1
# 4  Retail Food - Seasonal Lakefront Food Establishment       lakefront      2

# %% [markdown]
# ### Checks for missing values

# %%
# Check for missing values for location
no_location = business_license_v3_food[business_license_v3_food['location'].isna()]
# no_location

no_location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96 entries, 3707 to 153095
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   license_id              96 non-null     int64
#  1   doing_business_as_name  96 non-null     object
#  2   legal_name              96 non-null     object
#  3   license_description     96 non-null     object
#  4   business_activity       96 non-null     object
#  5   latitude                96 non-null     float64
#  6   longitude               96 non-null     float64
#  7   city                    96 non-null     object
#  8   state                   96 non-null     object
#  9   address                 96 non-null     object
#  10  zip_code                95 non-null     object
#  11  location                0 non-null      object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 9.8+ KB

# %%
# Check for missing values for location
no_zip_code = business_license_v3_food[business_license_v3_food['zip_code'].isna()]
no_zip_code

# no_zip_code.info()
# Out:
#         license_id                     doing_business_as_name                      legal_name           license_description                                                                                                                           business_activity   latitude  longitude     city state                          address zip_code                                                                    location
# 15905      2966309                TAQUERIA MI PUEBLO III INC.     TAQUERIA MI PUEBLO III INC.     Retail Food Establishment                                                                                     Preparation of Food and Dining on Premises With Seating  41.801005 -87.686616  CHICAGO    IL                 2459 W 51ST ST 1      NaN   {"type": "Point", "coordinates": [-87.68661612013953, 41.80100543752876]}
# 16866      2970835                            MANRRAS GROCERY           MANRRAS GROCERY, INC.     Retail Food Establishment  Retail Sales of Fresh Fruits and Vegetables (Leafy and Non Leafy Vegetables) | Retail Sales of General Merchandise and Non-Perishable Food  41.846461 -87.703804  CHICAGO    IL                   3132 W 25TH ST      NaN   {"type": "Point", "coordinates": [-87.7038037640727, 41.846460663996105]}
# 17967      2943276                                 MCDONALD'S                     CAGUAX LTD.     Retail Food Establishment                                                                                            Sale of Food Prepared Onsite Without Dining Area  42.008970 -87.906897  CHICAGO    IL       11600 W TOUHY AVE  T-3 H&K      NaN  {"type": "Point", "coordinates": [-87.90689745006604, 42.008969609166535]}
# 31596      2958652                    Fulton Market - Chicago              FULTON TROIKA, LLC  Wholesale Food Establishment                                                                           Direct Food Sales to Businesses | Enagage in Wholesale Food Sales  41.816068 -87.736017  CHICAGO    IL          4501 W ANN LURIE PL 1ST      NaN  {"type": "Point", "coordinates": [-87.73601666681014, 41.816068222595995]}
# 122281     2984211  Home Run Inn Pizza T2E Conc. Site NO. 104        HOST INTERNATIONAL, INC.     Retail Food Establishment                                                                                            Sale of Food Prepared Onsite Without Dining Area  42.008751 -87.906874  CHICAGO    IL      11601 W TOUHY AVE  T2 E CON      NaN   {"type": "Point", "coordinates": [-87.90687413400109, 42.00875076599798]}
# 122337     2984212                        Carry Out, Carry On        HOST INTERNATIONAL, INC.     Retail Food Establishment                                              Retail Sales of General Merchandise and Non-Perishable Food | Retail Sales of Perishable Foods  42.008751 -87.906874  CHICAGO    IL      11601 W TOUHY AVE  T2 E CON      NaN   {"type": "Point", "coordinates": [-87.90687413400109, 42.00875076599798]}
# 122385     2965608                     AUNTIE ANNE'S PRETZELS       FRESH DINING CONCEPTS LLC     Retail Food Establishment                                                                                            Sale of Food Prepared Onsite Without Dining Area  42.008751 -87.906874  CHICAGO    IL           11601 W TOUHY AVE  2EF      NaN   {"type": "Point", "coordinates": [-87.90687413400109, 42.00875076599798]}
# 122429     2950430                            Green Market L6  O'HARE POPCORN & FOODS, L.L.C.     Retail Food Establishment                                              Retail Sales of General Merchandise and Non-Perishable Food | Retail Sales of Perishable Foods  42.008751 -87.906874  CHICAGO    IL  11601 W TOUHY AVE TERMINAL 3 L6      NaN   {"type": "Point", "coordinates": [-87.90687413400109, 42.00875076599798]}
# 122649     2916095                            HALE MCDONALD'S        INFINITE BUENA VIDA, LLC     Retail Food Establishment                                                                                               Sale of Food Prepared Onsite With Dining Area  42.008751 -87.906874  CHICAGO    IL    11601 W TOUHY AVE  TERMINAL 5      NaN   {"type": "Point", "coordinates": [-87.90687413400109, 42.00875076599798]}
# 122947     2965607                     AUNTIE ANNE'S PRETZELS       FRESH DINING CONCEPTS LLC     Retail Food Establishment                                                                                            Sale of Food Prepared Onsite Without Dining Area  42.008751 -87.906874  CHICAGO    IL            11601 W TOUHY AVE  1C      NaN   {"type": "Point", "coordinates": [-87.90687413400109, 42.00875076599798]}

# %% [markdown]
# # 2.2 Population counts

# %% [markdown]
# ### Exploration
# - no duplicates
# - remove 1st row as it a city wide (probably used to calculate percentages)
# - keep 2021 as it is the latest year (transformation will be needed if want to calculate the YoY increase in population, also not a good year to use as it is during covid)
# - zipcode is cast as geography type, to keep in mind when joining with other tables later on
# - remove rows: geography type, record_id
# - keep population_other with NaN, keep in mind if using for model

# %%
population_counts.head()
# Out:
#   geography_type  year zip_code  population_total  population_0_to_17  \
# 0       Citywide  2018  Chicago           2705988              548999
# 1       ZIP Code  2018    60601             14675                 820
# 2       ZIP Code  2018    60602              1244                 149
# 3       ZIP Code  2018    60603              1174                  56
# 4       ZIP Code  2018    60604               782                  38
#
#    population_18_to_29  population_30_to_39  population_40_to_49  \
# 0               552935               456321               336457
# 1                 4606                 2792                 2190
# 2                  435                  462                  135
# 3                  561                  101                   97
# 4                  303                  104                   51
#
#    population_50_to_59  population_60_to_69  population_70_to_79  \
# 0               312965               262991               155334
# 1                 1333                 1340                 1272
# 2                   53                   10                    0
# 3                  197                   97                   65
# 4                  101                  130                   50
#
#    population_80  population_female  population_male  population_latinx  \
# 0          79986            1386113          1319875             776661
# 1            322               7484             7191               1274
# 2              0                551              693                 81
# 3              0                601              573                115
# 4              5                413              369                 34
#
#    population_asian  population_black  population_white  population_other  \
# 0          179841.0          784266.0            899980          119467.0
# 1               NaN               NaN              9677               NaN
# 2               NaN               NaN               788               NaN
# 3               NaN               NaN               707               NaN
# 4               NaN               NaN               479               NaN
#
#                record_id
# 0  Citywide-Chicago-2018
# 1    ZIP_Code-60601-2018
# 2    ZIP_Code-60602-2018
# 3    ZIP_Code-60603-2018
# 4    ZIP_Code-60604-2018

# %%
from summarytools import dfSummary
dfSummary(population_counts)
# Out:
# <style type="text/css">
# #T_70746 thead>tr>th {
#   text-align: left;
# }
# #T_70746_row0_col0, #T_70746_row1_col0, #T_70746_row2_col0, #T_70746_row3_col0, #T_70746_row4_col0, #T_70746_row5_col0, #T_70746_row6_col0, #T_70746_row7_col0, #T_70746_row8_col0, #T_70746_row9_col0, #T_70746_row10_col0, #T_70746_row11_col0, #T_70746_row12_col0, #T_70746_row13_col0, #T_70746_row14_col0, #T_70746_row15_col0, #T_70746_row16_col0, #T_70746_row17_col0, #T_70746_row18_col0, #T_70746_row19_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_70746_row0_col1, #T_70746_row1_col1, #T_70746_row2_col1, #T_70746_row3_col1, #T_70746_row4_col1, #T_70746_row5_col1, #T_70746_row6_col1, #T_70746_row7_col1, #T_70746_row8_col1, #T_70746_row9_col1, #T_70746_row10_col1, #T_70746_row11_col1, #T_70746_row12_col1, #T_70746_row13_col1, #T_70746_row14_col1, #T_70746_row15_col1, #T_70746_row16_col1, #T_70746_row17_col1, #T_70746_row18_col1, #T_70746_row19_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_70746_row0_col2, #T_70746_row1_col2, #T_70746_row2_col2, #T_70746_row3_col2, #T_70746_row4_col2, #T_70746_row5_col2, #T_70746_row6_col2, #T_70746_row7_col2, #T_70746_row8_col2, #T_70746_row9_col2, #T_70746_row10_col2, #T_70746_row11_col2, #T_70746_row12_col2, #T_70746_row13_col2, #T_70746_row14_col2, #T_70746_row15_col2, #T_70746_row16_col2, #T_70746_row17_col2, #T_70746_row18_col2, #T_70746_row19_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_70746_row0_col3, #T_70746_row1_col3, #T_70746_row2_col3, #T_70746_row3_col3, #T_70746_row4_col3, #T_70746_row5_col3, #T_70746_row6_col3, #T_70746_row7_col3, #T_70746_row8_col3, #T_70746_row9_col3, #T_70746_row10_col3, #T_70746_row11_col3, #T_70746_row12_col3, #T_70746_row13_col3, #T_70746_row14_col3, #T_70746_row15_col3, #T_70746_row16_col3, #T_70746_row17_col3, #T_70746_row18_col3, #T_70746_row19_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_70746_row0_col4, #T_70746_row1_col4, #T_70746_row2_col4, #T_70746_row3_col4, #T_70746_row4_col4, #T_70746_row5_col4, #T_70746_row6_col4, #T_70746_row7_col4, #T_70746_row8_col4, #T_70746_row9_col4, #T_70746_row10_col4, #T_70746_row11_col4, #T_70746_row12_col4, #T_70746_row13_col4, #T_70746_row14_col4, #T_70746_row15_col4, #T_70746_row16_col4, #T_70746_row17_col4, #T_70746_row18_col4, #T_70746_row19_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_70746_row0_col5, #T_70746_row1_col5, #T_70746_row2_col5, #T_70746_row3_col5, #T_70746_row4_col5, #T_70746_row5_col5, #T_70746_row6_col5, #T_70746_row7_col5, #T_70746_row8_col5, #T_70746_row9_col5, #T_70746_row10_col5, #T_70746_row11_col5, #T_70746_row12_col5, #T_70746_row13_col5, #T_70746_row14_col5, #T_70746_row15_col5, #T_70746_row16_col5, #T_70746_row17_col5, #T_70746_row18_col5, #T_70746_row19_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_70746">
#   <caption><strong>Data Frame Summary</strong><br>population_counts<br>Dimensions: 235 x 20<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_70746_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_70746_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_70746_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_70746_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_70746_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_70746_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_70746_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_70746_row0_col1" class="data row0 col1" ><strong>geography_type</strong><br>[object]</td>
#       <td id="T_70746_row0_col2" class="data row0 col2" >1. ZIP Code<br>2. Citywide</td>
#       <td id="T_70746_row0_col3" class="data row0 col3" >231 (98.3%)<br>4 (1.7%)</td>
#       <td id="T_70746_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_70746_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_70746_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_70746_row1_col1" class="data row1 col1" ><strong>year</strong><br>[int64]</td>
#       <td id="T_70746_row1_col2" class="data row1 col2" >1. 2018<br>2. 2019<br>3. 2021<br>4. 2020</td>
#       <td id="T_70746_row1_col3" class="data row1 col3" >60 (25.5%)<br>60 (25.5%)<br>60 (25.5%)<br>55 (23.4%)</td>
#       <td id="T_70746_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_70746_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_70746_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_70746_row2_col1" class="data row2 col1" ><strong>zip_code</strong><br>[object]</td>
#       <td id="T_70746_row2_col2" class="data row2 col2" >1. Chicago<br>2. 60601<br>3. 60633<br>4. 60634<br>5. 60636<br>6. 60637<br>7. 60638<br>8. 60639<br>9. 60640<br>10. 60641<br>11. other</td>
#       <td id="T_70746_row2_col3" class="data row2 col3" >4 (1.7%)<br>4 (1.7%)<br>4 (1.7%)<br>4 (1.7%)<br>4 (1.7%)<br>4 (1.7%)<br>4 (1.7%)<br>4 (1.7%)<br>4 (1.7%)<br>4 (1.7%)<br>195 (83.0%)</td>
#       <td id="T_70746_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_70746_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_70746_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_70746_row3_col1" class="data row3 col1" ><strong>population_total</strong><br>[int64]</td>
#       <td id="T_70746_row3_col2" class="data row3 col2" >Mean (sd) : 91792.9 (344775.7)<br>min < med < max:<br>0.0 < 46591.0 < 2705988.0<br>IQR (CV) : 40016.5 (0.3)</td>
#       <td id="T_70746_row3_col3" class="data row3 col3" >230 distinct values</td>
#       <td id="T_70746_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_70746_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_70746_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_70746_row4_col1" class="data row4 col1" ><strong>population_0_to_17</strong><br>[int64]</td>
#       <td id="T_70746_row4_col2" class="data row4 col2" >Mean (sd) : 18856.4 (70287.3)<br>min < med < max:<br>0.0 < 8949.0 < 555424.0<br>IQR (CV) : 9281.5 (0.3)</td>
#       <td id="T_70746_row4_col3" class="data row4 col3" >230 distinct values</td>
#       <td id="T_70746_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_70746_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_70746_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_70746_row5_col1" class="data row5 col1" ><strong>population_18_to_29</strong><br>[int64]</td>
#       <td id="T_70746_row5_col2" class="data row5 col2" >Mean (sd) : 18423.1 (68648.7)<br>min < med < max:<br>0.0 < 8405.0 < 552935.0<br>IQR (CV) : 8569.5 (0.3)</td>
#       <td id="T_70746_row5_col3" class="data row5 col3" >227 distinct values</td>
#       <td id="T_70746_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_70746_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_70746_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_70746_row6_col1" class="data row6 col1" ><strong>population_30_to_39</strong><br>[int64]</td>
#       <td id="T_70746_row6_col2" class="data row6 col2" >Mean (sd) : 15717.5 (59241.0)<br>min < med < max:<br>0.0 < 7125.0 < 469300.0<br>IQR (CV) : 6692.5 (0.3)</td>
#       <td id="T_70746_row6_col3" class="data row6 col3" >229 distinct values</td>
#       <td id="T_70746_row6_col4" class="data row6 col

# %% [markdown]
# ## Cleaning & transformation
# - remove col: geography type, record_id
# - remove 1st row as it a city wide (probably used to calculate percentages)
# - keep 2021 as it is the latest year (transformation will be needed if want to calculate the YoY increase in population, also not a good year to use as it is during covid)
# - Cast population_asian,population_black, population_other to int64

# %%
# Code for script
population_counts_v2 = population_counts.drop(['geography_type','record_id'],axis=1)
population_counts_v2 = population_counts_v2[population_counts['zip_code'] != 'Chicago']
population_counts_v3 = population_counts_v2[population_counts_v2['year']==2021]

# %%
population_counts.tail()
# Out:
#     geography_type  year zip_code  population_total  population_0_to_17  \
# 230       ZIP Code  2021    60626             50295                8007
# 231       ZIP Code  2021    60628             64489               13734
# 232       ZIP Code  2021    60629            107487               29283
# 233       ZIP Code  2021    60630             55591               11093
# 234       ZIP Code  2021    60631             30589                6925
#
#      population_18_to_29  population_30_to_39  population_40_to_49  \
# 230                11937                 8965                 6995
# 231                11638                 7491                 7593
# 232                20690                13227                14954
# 233                 7053                 8926                 7337
# 234                 3308                 4357                 3813
#
#      population_50_to_59  population_60_to_69  population_70_to_79  \
# 230                 6738                 4360                 2178
# 231                 9066                 6930                 4860
# 232                11096                 8187                 7688
# 233                 7479                 7975                 3605
# 234                 4657                 3686                 1846
#
#      population_80  population_female  population_male  population_latinx  \
# 230           1115              25318            24977               9694
# 231           3177              34961            29528               2775
# 232           2362              53753            53734              79111
# 233           2123              27787            27804              14180
# 234           1997              15516            15073               4491
#
#      population_asian  population_black  population_white  population_other  \
# 230            2724.0           12646.0             23029            2202.0
# 231              79.0           59168.0              1462            1005.0
# 232             595.0           18878.0              7650            1253.0
# 233            7122.0            1007.0             31325            1957.0
# 234            1262.0             307.0             23360            1169.0
#
#                record_id
# 230  ZIP_CODE-60626-2021
# 231  ZIP_CODE-60628-2021
# 232  ZIP_CODE-60629-2021
# 233  ZIP_CODE-60630-2021
# 234  ZIP_CODE-60631-2021

# %%
population_counts_v2 = population_counts.drop(['geography_type','record_id'],axis=1)
population_counts_v2 = population_counts_v2[population_counts['zip_code'] != 'Chicago']
population_counts_v3 = population_counts_v2[population_counts_v2['year']==2021]
population_counts_v3.head()
# Out:
#      year zip_code  population_total  population_0_to_17  population_18_to_29  \
# 176  2021    60601             14804                 999                 5065
# 177  2021    60602              1142                 119                  163
# 178  2021    60603              1275                  33                  399
# 179  2021    60604               687                   6                  335
# 180  2021    60605             32077                2841                 9038
#
#      population_30_to_39  population_40_to_49  population_50_to_59  \
# 176                 3739                 1390                  970
# 177                  658                   67                   95
# 178                  266                   81                  196
# 179                  122                   38                   74
# 180                 8714                 3740                 3127
#
#      population_60_to_69  population_70_to_79  population_80  \
# 176                 1515                  910            216
# 177                   33                    7              0
# 178                  191                   93             16
# 179                   61                   33             18
# 180                 2539                 1640            438
#
#      population_female  population_male  population_latinx  population_asian  \
# 176               8260             6544               1234            3827.0
# 177                540              602                311             101.0
# 178                595              680                 78             397.0
# 179                421              266                 30              70.0
# 180              16395            15682               2841            4942.0
#
#      population_black  population_white  population_other
# 176             908.0              8124             711.0
# 177              38.0               537             155.0
# 178              71.0               723               6.0
# 179              72.0               515               0.0
# 180            4571.0             18296            1427.0

# %% [markdown]
# ## Check its clean

# %%
population_counts_v3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 176 to 234
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 59 non-null     int64
#  1   zip_code             59 non-null     object
#  2   population_total     59 non-null     int64
#  3   population_0_to_17   59 non-null     int64
#  4   population_18_to_29  59 non-null     int64
#  5   population_30_to_39  59 non-null     int64
#  6   population_40_to_49  59 non-null     int64
#  7   population_50_to_59  59 non-null     int64
#  8   population_60_to_69  59 non-null     int64
#  9   population_70_to_79  59 non-null     int64
#  10  population_80        59 non-null     int64
#  11  population_female    59 non-null     int64
#  12  population_male      59 non-null     int64
#  13  population_latinx    59 non-null     int64
#  14  population_asian     59 non-null     float64
#  15  population_black     59 non-null     float64
#  16  population_white     59 non-null     int64
#  17  population_other     59 non-null     float64
# dtypes: float64(3), int64(14), object(1)
# memory usage: 8.8+ KB

# %%
dfSummary(population_counts_v3)
# Out:
# <style type="text/css">
# #T_87105 thead>tr>th {
#   text-align: left;
# }
# #T_87105_row0_col0, #T_87105_row1_col0, #T_87105_row2_col0, #T_87105_row3_col0, #T_87105_row4_col0, #T_87105_row5_col0, #T_87105_row6_col0, #T_87105_row7_col0, #T_87105_row8_col0, #T_87105_row9_col0, #T_87105_row10_col0, #T_87105_row11_col0, #T_87105_row12_col0, #T_87105_row13_col0, #T_87105_row14_col0, #T_87105_row15_col0, #T_87105_row16_col0, #T_87105_row17_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_87105_row0_col1, #T_87105_row1_col1, #T_87105_row2_col1, #T_87105_row3_col1, #T_87105_row4_col1, #T_87105_row5_col1, #T_87105_row6_col1, #T_87105_row7_col1, #T_87105_row8_col1, #T_87105_row9_col1, #T_87105_row10_col1, #T_87105_row11_col1, #T_87105_row12_col1, #T_87105_row13_col1, #T_87105_row14_col1, #T_87105_row15_col1, #T_87105_row16_col1, #T_87105_row17_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_87105_row0_col2, #T_87105_row1_col2, #T_87105_row2_col2, #T_87105_row3_col2, #T_87105_row4_col2, #T_87105_row5_col2, #T_87105_row6_col2, #T_87105_row7_col2, #T_87105_row8_col2, #T_87105_row9_col2, #T_87105_row10_col2, #T_87105_row11_col2, #T_87105_row12_col2, #T_87105_row13_col2, #T_87105_row14_col2, #T_87105_row15_col2, #T_87105_row16_col2, #T_87105_row17_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_87105_row0_col3, #T_87105_row1_col3, #T_87105_row2_col3, #T_87105_row3_col3, #T_87105_row4_col3, #T_87105_row5_col3, #T_87105_row6_col3, #T_87105_row7_col3, #T_87105_row8_col3, #T_87105_row9_col3, #T_87105_row10_col3, #T_87105_row11_col3, #T_87105_row12_col3, #T_87105_row13_col3, #T_87105_row14_col3, #T_87105_row15_col3, #T_87105_row16_col3, #T_87105_row17_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_87105_row0_col4, #T_87105_row1_col4, #T_87105_row2_col4, #T_87105_row3_col4, #T_87105_row4_col4, #T_87105_row5_col4, #T_87105_row6_col4, #T_87105_row7_col4, #T_87105_row8_col4, #T_87105_row9_col4, #T_87105_row10_col4, #T_87105_row11_col4, #T_87105_row12_col4, #T_87105_row13_col4, #T_87105_row14_col4, #T_87105_row15_col4, #T_87105_row16_col4, #T_87105_row17_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_87105_row0_col5, #T_87105_row1_col5, #T_87105_row2_col5, #T_87105_row3_col5, #T_87105_row4_col5, #T_87105_row5_col5, #T_87105_row6_col5, #T_87105_row7_col5, #T_87105_row8_col5, #T_87105_row9_col5, #T_87105_row10_col5, #T_87105_row11_col5, #T_87105_row12_col5, #T_87105_row13_col5, #T_87105_row14_col5, #T_87105_row15_col5, #T_87105_row16_col5, #T_87105_row17_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_87105">
#   <caption><strong>Data Frame Summary</strong><br>population_counts_v3<br>Dimensions: 59 x 18<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_87105_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_87105_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_87105_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_87105_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_87105_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_87105_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_87105_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_87105_row0_col1" class="data row0 col1" ><strong>year</strong><br>[int64]</td>
#       <td id="T_87105_row0_col2" class="data row0 col2" >1. 2021</td>
#       <td id="T_87105_row0_col3" class="data row0 col3" >59 (100.0%)</td>
#       <td id="T_87105_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_87105_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_87105_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_87105_row1_col1" class="data row1 col1" ><strong>zip_code</strong><br>[object]</td>
#       <td id="T_87105_row1_col2" class="data row1 col2" >1. 60601<br>2. 60654<br>3. 60640<br>4. 60641<br>5. 60642<br>6. 60643<br>7. 60644<br>8. 60645<br>9. 60646<br>10. 60647<br>11. other</td>
#       <td id="T_87105_row1_col3" class="data row1 col3" >1 (1.7%)<br>1 (1.7%)<br>1 (1.7%)<br>1 (1.7%)<br>1 (1.7%)<br>1 (1.7%)<br>1 (1.7%)<br>1 (1.7%)<br>1 (1.7%)<br>1 (1.7%)<br>49 (83.1%)</td>
#       <td id="T_87105_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_87105_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_87105_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_87105_row2_col1" class="data row2 col1" ><strong>population_total</strong><br>[int64]</td>
#       <td id="T_87105_row2_col2" class="data row2 col2" >Mean (sd) : 47337.3 (26139.8)<br>min < med < max:<br>0.0 < 47630.0 < 107487.0<br>IQR (CV) : 36629.0 (1.8)</td>
#       <td id="T_87105_row2_col3" class="data row2 col3" >59 distinct values</td>
#       <td id="T_87105_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_87105_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_87105_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_87105_row3_col1" class="data row3 col1" ><strong>population_0_to_17</strong><br>[int64]</td>
#       <td id="T_87105_row3_col2" class="data row3 col2" >Mean (sd) : 9683.8 (6702.7)<br>min < med < max:<br>0.0 < 8652.0 < 29283.0<br>IQR (CV) : 8309.0 (1.4)</td>
#       <td id="T_87105_row3_col3" class="data row3 col3" >59 distinct values</td>
#       <td id="T_87105_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_87105_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_87105_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_87105_row4_col1" class="data row4 col1" ><strong>population_18_to_29</strong><br>[int64]</td>
#       <td id="T_87105_row4_col2" class="data row4 col2" >Mean (sd) : 9371.0 (5775.4)<br>min < med < max:<br>0.0 < 8272.0 < 23860.0<br>IQR (CV) : 7683.5 (1.6)</td>
#       <td id="T_87105_row4_col3" class="data row4 col3" >59 distinct values</td>
#       <td id="T_87105_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_87105_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_87105_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_87105_row5_col1" class="data row5 col1" ><strong>population_30_to_39</strong><br>[int64]</td>
#       <td id="T_87105_row5_col2" class="data row5 col2" >Mean (sd) : 8136.7 (5080.0)<br>min < med < max:<br>0.0 < 7356.0 < 22494.0<br>IQR (CV) : 6036.0 (1.6)</td>
#       <td id="T_87105_row5_col3" class="data row5 col3" >59 distinct values</td>
#       <td id="T_87105_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_87105_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_87105_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_87105_row6_col1" class="data row6 col1" ><strong>population_40_to_49</strong><br>[int64]</td>
#       <td id="T_87105_row6_col2" class="data row6 col2" >Mean (sd) : 5961.3 (3610.5)<br>min < med < max:<br>0.0 < 5835.0 < 15333.0<br>IQR (CV) : 4674.5 (1.7)</td>
#       <td id="T_87105_row6_col3" class="data row6 col3" >59 distinct values</td>
#       <td id="T_87105_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_87105_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_87105_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_87105_row7_col1" class="data row7 col1" ><strong>population_

# %% [markdown]
# # 2.3 Zoning data
# ## Notes
# -

# %%
zoning_data = pd.read_csv('data_exports/zoning_data.csv', header='infer')
zoning_data.head()
# Out:
#                                             geometry  case_number  zoning_id  \
# 0  {"type": "MultiPolygon", "coordinates": [[[[-8...            0         39
# 1  {"type": "MultiPolygon", "coordinates": [[[[-8...        15249         56
# 2  {"type": "MultiPolygon", "coordinates": [[[[-8...        16698         65
# 3  {"type": "MultiPolygon", "coordinates": [[[[-8...            0          5
# 4  {"type": "MultiPolygon", "coordinates": [[[[-8...        19319         25
#
#    zone_type zone_class                create_date                  edit_date  \
# 0          7       DX-3  2002-08-08 00:00:00+00:00  2021-10-27 00:00:00+00:00
# 1          4     RM-5.5  2005-11-22 00:00:00+00:00  2021-10-27 00:00:00+00:00
# 2         11          T  2006-09-21 00:00:00+00:00  2021-10-27 00:00:00+00:00
# 3          1       B1-5  2002-07-25 00:00:00+00:00  2021-10-27 00:00:00+00:00
# 4          2       C3-2  2007-07-17 00:00:00+00:00  2021-10-27 00:00:00+00:00
#
#      edit_uid  pd_num     shape_area    shape_len  objectid  \
# 0  DATA_ADMIN       0   33774.058205  1000.462511   1913402
# 1  DATA_ADMIN       0   20352.881358   594.244454   1913414
# 2  DATA_ADMIN       0   77862.423343  1606.934885   1913472
# 3  DATA_ADMIN       0  207332.769978  2422.030931   1913485
# 4  DATA_ADMIN       0  118844.776139  1618.678198   1913507
#
#                                  globalid  override_r
# 0  {124FD442-84B5-4986-BC6B-1EBE5ACEAC8D}           0
# 1  {BA02CDBA-C84D-41BB-9E89-D00C5DCB376B}           0
# 2  {A9BF5B94-571C-40B7-9FD3-9233B9C64B51}           0
# 3  {C47E39FC-D5BB-44F3-B35C-52B885C5BA8D}           0
# 4  {6304CEC6-81D6-43A9-AB98-8F6BC6B07085}           0

# %%
# Load in zone type description
zoning_details = pd.read_csv('data_exports/zoning-code-summary-district-types.csv',header = 'infer')
# Drop zone_type & old_description
zoning_details_v2 = zoning_details.drop(['zone_type','old_description','old_zoning_ordinance_code'],axis=1)
# rename columns
zoning_details_v2 = zoning_details_v2.rename(columns={
    'district_type_code': 'zone_class',
    'juan_description': 'description'
})

zoning_details_v2.head()
# Out:
#   zone_class                                        description  \
# 0       B1-1  Retail storefronts on low-traffic streets. Apa...
# 1     B1-1.5  Retail storefronts on low-traffic streets. Apa...
# 2       B1-2  Retail storefronts on low-traffic streets. Apa...
# 3       B1-3  Retail storefronts on low-traffic streets. Apa...
# 4       B1-5  Retail storefronts on low-traffic streets. Apa...
#
#                    district_title zoning_code_section floor_area_ratio  \
# 0  Neighborhood Shopping District           17-3-0102              1.2
# 1  Neighborhood Shopping District           17-3-0102              1.5
# 2  Neighborhood Shopping District           17-3-0102              2.2
# 3  Neighborhood Shopping District           17-3-0102                3
# 4  Neighborhood Shopping District           17-3-0102                5
#
#                              maximum_building_height  \
# 0  Varies by lot frontage, and whether building h...
# 1  Varies by lot frontage, and whether building h...
# 2  Varies by lot frontage, and whether building h...
# 3  Varies by lot frontage, and whether building h...
# 4  Varies by lot frontage, and whether building h...
#
#                                    lot_area_per_unit  \
# 0  2,500 sq ft/dwelling unit, 2,500 sq ft/efficie...
# 1  1,350 sq ft/dwelling unit, 1,350 sq ft/efficie...
# 2  1,000 sq ft/dwelling unit, 700 sq ft/efficienc...
# 3  400 sq ft/dwelling unit, 300 sq ft/efficiency ...
# 4  200 sq ft/dwelling unit, 135 sq ft/efficiency ...
#
#                                   front_yard_setback  \
# 0  None, unless property borders an R-zoned lot. ...
# 1  None, unless property borders an R-zoned lot. ...
# 2  None, unless property borders an R-zoned lot. ...
# 3  None, unless property borders an R-zoned lot. ...
# 4  None, unless property borders an R-zoned lot. ...
#
#                                         side_setback  \
# 0  None, unless property borders an R-zoned lot. ...
# 1  None, unless property borders an R-zoned lot. ...
# 2  None, unless property borders an R-zoned lot. ...
# 3  None, unless property borders an R-zoned lot. ...
# 4  None, unless property borders an R-zoned lot. ...
#
#                                    rear_yard_setback rear_yard_open_space  \
# 0  If property has dwelling units, minimum of 30 ...                  NaN
# 1  If property has dwelling units, minimum of 30 ...                  NaN
# 2  If property has dwelling units, minimum of 30 ...                  NaN
# 3  If property has dwelling units, minimum of 30 ...                  NaN
# 4  If property has dwelling units, minimum of 30 ...                  NaN
#
#   on_site_open_space minimum_lot_area
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN

# %%
district_view = zoning_details_v2['district_title'].value_counts(dropna=False).reset_index().rename(columns={
    'index': 'district_title',
    'district_title': 'district_title'
})
district_view
# Out:
#                                        district_title  count
# 0                      Neighborhood Shopping District      5
# 1                         Community Shopping District      5
# 2                    Neighborhood Commercial District      5
# 3                         Downtown Mixed-Use District      5
# 4                     Residential Multi-Unit District      5
# 5                     Neighborhood Mixed-Use District      5
# 6           Motor Vehicle-Related Commercial District      4
# 7   Commercial, Manufacturing and Employment District      4
# 8                       Downtown Residential District      4
# 9                             Heavy Industry District      3
# 10  Residential Two-Flat, Townhouse and Multi-Unit...      3
# 11                   Residential Single-Unit District      3
# 12                            Light Industry District      3
# 13       Limited Manufacturing/Business Park District      3
# 14                          Downtown Service District      2
# 15                             Downtown Core District      2
# 16                               Planned Developments      1
# 17                    Planned Manufacturing Districts      1
# 18                         Regional or Community Park      1
# 19           Neighborhood Park, Mini-Park, or Playlot      1
# 20                         Open Space or Natural Area      1
# 21                            Transportation District      1

# %% [markdown]
# ## Cleaning & Transformation

# %%
col_to_keep = ['geometry',
'zoning_id',
'zone_class',
'edit_date',
'shape_area',
'shape_len',
'objectid'
]
zoning_data_v2 = zoning_data[col_to_keep]
zoning_data_v3 = pd.merge(zoning_data_v2, zoning_details_v2, on='zone_class', how='left')

# Add a boolean column for zone_class cols that can have restaurants
def add_restaurant_allowed(df):
    licenses = ["B1", "B2", "B3", "C1", "C2", "C3", "DC", "DX", "DS", "M1", "M2", "M3","PMD"]
    pattern = '|'.join(licenses)
    df['restaurant_allowed'] = np.where(df['zone_class'].str.contains(pattern, na=False), 1, 0)
    return df

zoning_data_v4 = add_restaurant_allowed(zoning_data_v3)

zoning_data_v4
# Out:
#                                                 geometry  zoning_id  \
# 0      {"type": "MultiPolygon", "coordinates": [[[[-8...         39
# 1      {"type": "MultiPolygon", "coordinates": [[[[-8...         56
# 2      {"type": "MultiPolygon", "coordinates": [[[[-8...         65
# 3      {"type": "MultiPolygon", "coordinates": [[[[-8...          5
# 4      {"type": "MultiPolygon", "coordinates": [[[[-8...         25
# ...                                                  ...        ...
# 14650  {"type": "MultiPolygon", "coordinates": [[[[-8...          9
# 14651  {"type": "MultiPolygon", "coordinates": [[[[-8...          9
# 14652  {"type": "MultiPolygon", "coordinates": [[[[-8...          9
# 14653  {"type": "MultiPolygon", "coordinates": [[[[-8...          9
# 14654  {"type": "MultiPolygon", "coordinates": [[[[-8...          9
#
#       zone_class                  edit_date     shape_area    shape_len  \
# 0           DX-3  2021-10-27 00:00:00+00:00   33774.058205  1000.462511
# 1         RM-5.5  2021-10-27 00:00:00+00:00   20352.881358   594.244454
# 2              T  2021-10-27 00:00:00+00:00   77862.423343  1606.934885
# 3           B1-5  2021-10-27 00:00:00+00:00  207332.769978  2422.030931
# 4           C3-2  2021-10-27 00:00:00+00:00  118844.776139  1618.678198
# ...          ...                        ...            ...          ...
# 14650       B2-3  2024-11-12 00:00:00+00:00       3.617172    57.689593
# 14651       B2-3  2024-12-16 00:00:00+00:00   36562.471714   781.031371
# 14652       B2-3  2024-12-16 00:00:00+00:00   12658.560728   456.983524
# 14653       B2-3  2024-12-12 00:00:00+00:00    9539.649105   390.314170
# 14654       B2-3  2024-11-14 00:00:00+00:00   16850.204801   530.148501
#
#        objectid                                        description  \
# 0       1913402  Downtown high-rises - offices or apartments - ...
# 1       1913414  Medium to high-density apartment buildings. Tw...
# 2       1913472  Bits of land designed to protect roads, bus wa...
# 3       1913485  Retail storefronts on low-traffic streets. Apa...
# 4       1913507  Businesses and factories, no housing allowed. ...
# ...         ...                                                ...
# 14650   1926477  Retail storefronts, apartments allowed on the ...
# 14651   1926631  Retail storefronts, apartments allowed on the ...
# 14652   1926632  Retail storefronts, apartments allowed on the ...
# 14653   1926633  Retail storefronts, apartments allowed on the ...
# 14654   1926576  Retail storefronts, apartments allowed on the ...
#
#                                           district_title zoning_code_section  \
# 0                            Downtown Mixed-Use District           17-4-0103
# 1                        Residential Multi-Unit District           17-2-0104
# 2                                Transportation District           17-6-0300
# 3                         Neighborhood Shopping District           17-3-0102
# 4      Commercial, Manufacturing and Employment District           17-3-0107
# ...                                                  ...                 ...
# 14650                    Neighborhood Mixed-Use District           17-3-0103
# 14651                    Neighborhood Mixed-Use District           17-3-0103
# 14652                    Neighborhood Mixed-Use District           17-3-0103
# 14653                    Neighborhood Mixed-Use District           17-3-0103
# 14654                    Neighborhood Mixed-Use District           17-3-0103
#
#       floor_area_ratio                            maximum_building_height  \
# 0                    3  None, but buildings taller than city's "buildi...
# 1                  2.5  47 ft for residential buildings with lot front...
# 2                  1.5                                                NaN
# 3                    5  Varies by lot frontage, and whether building h...
# 4                  2.2  Varies by lot frontage, and whether building h...
# ...                ...                                                ...
# 14650                3  Varies by lot frontage, and whether building h...
# 14651                3  Varies by lot frontage, and whether building h...
# 14652                3  Varies by lot frontage, and whether building h...
# 14653                3  Varies by lot frontage, and whether building h...
# 14654                3  Varies by lot frontage, and whether building h...
#
#                                        lot_area_per_unit  \
# 0      400 sq ft/dwelling unit, 300 sq ft/efficiency ...
# 1      400 sq ft/dwelling unit, 400 sq ft/efficiency ...
# 2                                                    NaN
# 3      200 sq ft/dwelling unit, 135 sq ft/efficiency ...
# 4      1,000 sq ft/dwelling unit, 700 sq ft/efficienc...
# ...                                                  ...
# 14650  400 sq ft/dwelling unit, 300 sq ft/efficiency ...
# 14651  400 sq ft/dwelling unit, 300 sq ft/efficiency ...
# 14652  400 sq ft/dwelling unit, 300 sq ft/efficiency ...
# 14653  400 sq ft/dwelling unit, 300 sq ft/efficiency ...
# 14654  400 sq ft/dwelling unit, 300 sq ft/efficiency ...
#
#                                       front_yard_setback  \
# 0                                                    NaN
# 1      15ft, or 12% of lot depth, whichever is less. ...
# 2                                                    NaN
# 3      None, unless property borders an R-zoned lot. ...
# 4      None, unless property borders an R-zoned lot. ...
# ...                                                  ...
# 14650  None, unless property borders an R-zoned lot. ...
# 14651  None, unless property borders an R-zoned lot. ...
# 14652  None, unless property borders an R-zoned lot. ...
# 14653  None, unless property borders an R-zoned lot. ...
# 14654  None, unless property borders an R-zoned lot. ...
#
#                                             side_setback  \
# 0                                                    NaN
# 1      Townhouses: complicated as hell, see 17-2-0500...
# 2                                                    NaN
# 3      None, unless property borders an R-zoned lot. ...
# 4      None, unless property borders an R-zoned lot. ...
# ...                                                  ...
# 14650  None, unless property borders an R-zoned lot. ...
# 14651  None, unless property borders an R-zoned lot. ...
# 14652  None, unless property borders an R-zoned lot. ...
# 14653  None, unless property borders an R-zoned lot. ...
# 14654  None, unless property borders an R-zoned lot. ...
#
#                                        rear_yard_setback rear_yard_open_space  \
# 0      30ft for floors containing dwelling units. All...                  NaN
# 1      For buildings with under 20 dwelling units, of...                  NaN
# 2                                                    NaN                  NaN
# 3      If property has dwelling units, minimum of 30 ...                  NaN
# 4      If property has dwelling units, minimum of 30 ...                  NaN
# ...                                                  ...                  ...
# 14650  If property has dwelling units, minimum of 30 ...                  NaN
# 14651  If property has dwelling units, minimum of 30 ...                  NaN
# 14652  If property has dwelling units, minimum of 30 ...                  NaN
# 14653  If property has dwelling units, minimum of 30 ...                  NaN
# 14654  If property has dwelling units, minimum of 30 ...                  NaN
#
#                                       on_site_open_space minimum_lot_area  \
# 0      All buildings with people living in them must ...              NaN
# 1      All buildings with people living in them must ...      1,650 sq ft
# 2                                                    NaN              NaN
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 14650                                                NaN              NaN
# 14651                                                NaN              NaN
# 14652                                                NaN              NaN
# 14653                                                NaN              NaN
# 14654                                                NaN              NaN
#
#        restaurant_allowed
# 0                       1
# 1                       0
# 2                       0
# 3                       1
# 4                       1
# ...                   ...
# 14650                   1
# 14651                   1
# 14652                   1
# 14653                   1
# 14654                   1
#
# [14655 rows x 20 columns]

# %% [markdown]
# ## Summary

# %%
dfSummary(zoning_data_v4)
# Out:
# <style type="text/css">
# #T_93bdf thead>tr>th {
#   text-align: left;
# }
# #T_93bdf_row0_col0, #T_93bdf_row1_col0, #T_93bdf_row2_col0, #T_93bdf_row3_col0, #T_93bdf_row4_col0, #T_93bdf_row5_col0, #T_93bdf_row6_col0, #T_93bdf_row7_col0, #T_93bdf_row8_col0, #T_93bdf_row9_col0, #T_93bdf_row10_col0, #T_93bdf_row11_col0, #T_93bdf_row12_col0, #T_93bdf_row13_col0, #T_93bdf_row14_col0, #T_93bdf_row15_col0, #T_93bdf_row16_col0, #T_93bdf_row17_col0, #T_93bdf_row18_col0, #T_93bdf_row19_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_93bdf_row0_col1, #T_93bdf_row1_col1, #T_93bdf_row2_col1, #T_93bdf_row3_col1, #T_93bdf_row4_col1, #T_93bdf_row5_col1, #T_93bdf_row6_col1, #T_93bdf_row7_col1, #T_93bdf_row8_col1, #T_93bdf_row9_col1, #T_93bdf_row10_col1, #T_93bdf_row11_col1, #T_93bdf_row12_col1, #T_93bdf_row13_col1, #T_93bdf_row14_col1, #T_93bdf_row15_col1, #T_93bdf_row16_col1, #T_93bdf_row17_col1, #T_93bdf_row18_col1, #T_93bdf_row19_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_93bdf_row0_col2, #T_93bdf_row1_col2, #T_93bdf_row2_col2, #T_93bdf_row3_col2, #T_93bdf_row4_col2, #T_93bdf_row5_col2, #T_93bdf_row6_col2, #T_93bdf_row7_col2, #T_93bdf_row8_col2, #T_93bdf_row9_col2, #T_93bdf_row10_col2, #T_93bdf_row11_col2, #T_93bdf_row12_col2, #T_93bdf_row13_col2, #T_93bdf_row14_col2, #T_93bdf_row15_col2, #T_93bdf_row16_col2, #T_93bdf_row17_col2, #T_93bdf_row18_col2, #T_93bdf_row19_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_93bdf_row0_col3, #T_93bdf_row1_col3, #T_93bdf_row2_col3, #T_93bdf_row3_col3, #T_93bdf_row4_col3, #T_93bdf_row5_col3, #T_93bdf_row6_col3, #T_93bdf_row7_col3, #T_93bdf_row8_col3, #T_93bdf_row9_col3, #T_93bdf_row10_col3, #T_93bdf_row11_col3, #T_93bdf_row12_col3, #T_93bdf_row13_col3, #T_93bdf_row14_col3, #T_93bdf_row15_col3, #T_93bdf_row16_col3, #T_93bdf_row17_col3, #T_93bdf_row18_col3, #T_93bdf_row19_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_93bdf_row0_col4, #T_93bdf_row1_col4, #T_93bdf_row2_col4, #T_93bdf_row3_col4, #T_93bdf_row4_col4, #T_93bdf_row5_col4, #T_93bdf_row6_col4, #T_93bdf_row7_col4, #T_93bdf_row8_col4, #T_93bdf_row9_col4, #T_93bdf_row10_col4, #T_93bdf_row11_col4, #T_93bdf_row12_col4, #T_93bdf_row13_col4, #T_93bdf_row14_col4, #T_93bdf_row15_col4, #T_93bdf_row16_col4, #T_93bdf_row17_col4, #T_93bdf_row18_col4, #T_93bdf_row19_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_93bdf_row0_col5, #T_93bdf_row1_col5, #T_93bdf_row2_col5, #T_93bdf_row3_col5, #T_93bdf_row4_col5, #T_93bdf_row5_col5, #T_93bdf_row6_col5, #T_93bdf_row7_col5, #T_93bdf_row8_col5, #T_93bdf_row9_col5, #T_93bdf_row10_col5, #T_93bdf_row11_col5, #T_93bdf_row12_col5, #T_93bdf_row13_col5, #T_93bdf_row14_col5, #T_93bdf_row15_col5, #T_93bdf_row16_col5, #T_93bdf_row17_col5, #T_93bdf_row18_col5, #T_93bdf_row19_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_93bdf">
#   <caption><strong>Data Frame Summary</strong><br>_<br>Dimensions: 14,655 x 20<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_93bdf_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_93bdf_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_93bdf_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_93bdf_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_93bdf_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_93bdf_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_93bdf_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_93bdf_row0_col1" class="data row0 col1" ><strong>geometry</strong><br>[object]</td>
#       <td id="T_93bdf_row0_col2" class="data row0 col2" >1. {"type": "MultiPolygon", "coor<br>2. {"type": "MultiPolygon", "coor<br>3. {"type": "MultiPolygon", "coor<br>4. {"type": "MultiPolygon", "coor<br>5. {"type": "MultiPolygon", "coor<br>6. {"type": "MultiPolygon", "coor<br>7. {"type": "MultiPolygon", "coor<br>8. {"type": "MultiPolygon", "coor<br>9. {"type": "MultiPolygon", "coor<br>10. {"type": "MultiPolygon", "coor<br>11. other</td>
#       <td id="T_93bdf_row0_col3" class="data row0 col3" >4 (0.0%)<br>2 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>14,641 (99.9%)</td>
#       <td id="T_93bdf_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_93bdf_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_93bdf_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_93bdf_row1_col1" class="data row1 col1" ><strong>zoning_id</strong><br>[int64]</td>
#       <td id="T_93bdf_row1_col2" class="data row1 col2" >Mean (sd) : 38.2 (388.4)<br>min < med < max:<br>0.0 < 42.0 < 46959.0<br>IQR (CV) : 50.0 (0.1)</td>
#       <td id="T_93bdf_row1_col3" class="data row1 col3" >69 distinct values</td>
#       <td id="T_93bdf_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_93bdf_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_93bdf_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_93bdf_row2_col1" class="data row2 col1" ><strong>zone_class</strong><br>[object]</td>
#       <td id="T_93bdf_row2_col2" class="data row2 col2" >1. RT-4<br>2. RS-3<br>3. B3-1<br>4. B3-2<br>5. RM-5<br>6. C1-2<br>7. B2-3<br>8. B1-1<br>9. C1-1<br>10. B3-3<br>11. other</td>
#       <td id="T_93bdf_row2_col3" class="data row2 col3" >1,932 (13.2%)<br>1,010 (6.9%)<br>849 (5.8%)<br>827 (5.6%)<br>718 (4.9%)<br>571 (3.9%)<br>549 (3.7%)<br>544 (3.7%)<br>531 (3.6%)<br>512 (3.5%)<br>6,612 (45.1%)</td>
#       <td id="T_93bdf_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_93bdf_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_93bdf_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_93bdf_row3_col1" class="data row3 col1" ><strong>edit_date</strong><br>[object]</td>
#       <td id="T_93bdf_row3_col2" class="data row3 col2" >1. 2021-10-27 00:00:00+00:00<br>2. 2023-10-03 00:00:00+00:00<br>3. 2023-11-14 00:00:00+00:00<br>4. 2024-10-31 00:00:00+00:00<br>5. 2024-06-03 00:00:00+00:00<br>6. 2023-02-03 00:00:00+00:00<br>7. 2024-05-20 00:00:00+00:00<br>8. 2021-11-24 00:00:00+00:00<br>9. 2024-11-01 00:00:00+00:00<br>10. 2022-12-07 00:00:00+00:00<br>11. other</td>
#       <td id="T_93bdf_row3_col3" class="data row3 col3" >8,211 (56.0%)<br>3,281 (22.4%)<br>192 (1.3%)<br>162 (1.1%)<br>129 (0.9%)<br>107 (0.7%)<br>106 (0.7%)<br>94 (0.6%)<br>94 (0.6%)<br>76 (0.5%)<br>2,203 (15.0%)</td>
#       <td id="T_93bdf_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_93bdf_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_93bdf_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_93bdf_row4_col1" class="data row4 col1" ><strong>shape_area</strong><br>[float64]</td>
#       <td id="T_93bdf_row4_col2" class="data row4 col2" >Mean (sd) : 439753.7 (3551145.3)<br>min < med < max:<br>0.0 < 33226.0 < 268547254.0<br>IQR (CV) : 121075.8 (0.1)</td>
#       <td id="T_93bdf_row4_col3" class="data row4 col3" >14,651 distinct values</td>
#       <td id="T_93bdf_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_93bdf_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_93bdf_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_93bdf_row5_col1" class="data row5 col1" ><strong>shape_len</strong><br>[float64]</td>
#       <td id="T_93bdf_row5_col2" class="data row5 col2" >Mean (sd)

# %%
zoning_data_v4.describe(include='all').T
# Out:
#                            count unique  \
# geometry                   14655  14651
# zoning_id                14655.0    NaN
# zone_class                 14655   1514
# edit_date                  14655    139
# shape_area               14655.0    NaN
# shape_len                14655.0    NaN
# objectid                 14655.0    NaN
# description                13176     24
# district_title             13176     20
# zoning_code_section        13176     20
# floor_area_ratio           13176     20
# maximum_building_height    13138     11
# lot_area_per_unit          13138     18
# front_yard_setback         12908      5
# side_setback               12852      8
# rear_yard_setback          13088      8
# rear_yard_open_space        4750      6
# on_site_open_space           513      2
# minimum_lot_area            4977      4
# restaurant_allowed       14655.0    NaN
#
#                                                                        top  \
# geometry                       {"type": "MultiPolygon", "coordinates": []}
# zoning_id                                                              NaN
# zone_class                                                            RT-4
# edit_date                                        2021-10-27 00:00:00+00:00
# shape_area                                                             NaN
# shape_len                                                              NaN
# objectid                                                               NaN
# description              Shopping centers, large stores, and retail sto...
# district_title                                 Community Shopping District
# zoning_code_section                                              17-3-0104
# floor_area_ratio                                                       1.2
# maximum_building_height  Varies by lot frontage, and whether building h...
# lot_area_per_unit        2,500 sq ft/dwelling unit, 2,500 sq ft/efficie...
# front_yard_setback       None, unless property borders an R-zoned lot. ...
# side_setback             None, unless property borders an R-zoned lot. ...
# rear_yard_setback        If property has dwelling units, minimum of 30 ...
# rear_yard_open_space     65 sq ft per dwelling unit, or 6.5% of the lot...
# on_site_open_space       All buildings with people living in them must ...
# minimum_lot_area                                               1,650 sq ft
# restaurant_allowed                                                     NaN
#
#                          freq           mean             std        min  \
# geometry                    4            NaN             NaN        NaN
# zoning_id                 NaN      38.227704      388.429092        0.0
# zone_class               1932            NaN             NaN        NaN
# edit_date                8211            NaN             NaN        NaN
# shape_area                NaN  439753.696474  3551145.270344        0.0
# shape_len                 NaN    2232.659197     5656.537885        0.0
# objectid                  NaN      1919427.0     4230.678433  1912100.0
# description              2370            NaN             NaN        NaN
# district_title           2370            NaN             NaN        NaN
# zoning_code_section      2370            NaN             NaN        NaN
# floor_area_ratio         4537            NaN             NaN        NaN
# maximum_building_height  6463            NaN             NaN        NaN
# lot_area_per_unit        2273            NaN             NaN        NaN
# front_yard_setback       6463            NaN             NaN        NaN
# side_setback             6463            NaN             NaN        NaN
# rear_yard_setback        6463            NaN             NaN        NaN
# rear_yard_open_space     1942            NaN             NaN        NaN
# on_site_open_space        286            NaN             NaN        NaN
# minimum_lot_area         3332            NaN             NaN        NaN
# restaurant_allowed        NaN       0.516206        0.499754        0.0
#
#                                   25%           50%            75%  \
# geometry                          NaN           NaN            NaN
# zoning_id                        11.0          42.0           61.0
# zone_class                        NaN           NaN            NaN
# edit_date                         NaN           NaN            NaN
# shape_area               11460.174713  33226.030826  132535.934139
# shape_len                  481.777924    784.931205    1841.040368
# objectid                    1915763.5     1919427.0      1923090.5
# description                       NaN           NaN            NaN
# district_title                    NaN           NaN            NaN
# zoning_code_section               NaN           NaN            NaN
# floor_area_ratio                  NaN           NaN            NaN
# maximum_building_height           NaN           NaN            NaN
# lot_area_per_unit                 NaN           NaN            NaN
# front_yard_setback                NaN           NaN            NaN
# side_setback                      NaN           NaN            NaN
# rear_yard_setback                 NaN           NaN            NaN
# rear_yard_open_space              NaN           NaN            NaN
# on_site_open_space                NaN           NaN            NaN
# minimum_lot_area                  NaN           NaN            NaN
# restaurant_allowed                0.0           1.0            1.0
#
#                                    max
# geometry                           NaN
# zoning_id                      46959.0
# zone_class                         NaN
# edit_date                          NaN
# shape_area               268547253.989
# shape_len                186946.249345
# objectid                     1926754.0
# description                        NaN
# district_title                     NaN
# zoning_code_section                NaN
# floor_area_ratio                   NaN
# maximum_building_height            NaN
# lot_area_per_unit                  NaN
# front_yard_setback                 NaN
# side_setback                       NaN
# rear_yard_setback                  NaN
# rear_yard_open_space               NaN
# on_site_open_space                 NaN
# minimum_lot_area                   NaN
# restaurant_allowed                 1.0

# %% [markdown]
# # 2.4 Bus Station Data

# %%
bus_data.head()
# Out:
#    longitude   latitude  systemstop        street                cross_st dir  \
# 0 -87.747509  41.956892     15189.0        CICERO     BERTEAU (north leg)  SB
# 1 -87.703980  41.805777      3082.0        KEDZIE  48TH PLACE (north leg)  SB
# 2 -87.640475  41.943530      1157.0    LAKE SHORE                  ROSCOE  NB
# 3 -87.585295  41.722579      7211.0  STONY ISLAND             95TH STREET  SB
# 4 -87.743174  41.802234      8123.0        CICERO             50TH STREET  SB
#
#   pos   routesstpg     city                  public_nam
# 0  FS       54,54A  CHICAGO            Cicero & Berteau
# 1  NS        47,52  CHICAGO         Kedzie & 48th Place
# 2  NT  135,146,151  CHICAGO         Lake Shore & Roscoe
# 3  NS     N5,28,95  CHICAGO  Stony Island & 95th Street
# 4  NS       47,54B  CHICAGO        Cicero & 50th Street

# %%
from summarytools import dfSummary
dfSummary(bus_data_v2)
# Out:
# <style type="text/css">
# #T_f2ac7 thead>tr>th {
#   text-align: left;
# }
# #T_f2ac7_row0_col0, #T_f2ac7_row1_col0, #T_f2ac7_row2_col0, #T_f2ac7_row3_col0, #T_f2ac7_row4_col0, #T_f2ac7_row5_col0, #T_f2ac7_row6_col0, #T_f2ac7_row7_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_f2ac7_row0_col1, #T_f2ac7_row1_col1, #T_f2ac7_row2_col1, #T_f2ac7_row3_col1, #T_f2ac7_row4_col1, #T_f2ac7_row5_col1, #T_f2ac7_row6_col1, #T_f2ac7_row7_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_f2ac7_row0_col2, #T_f2ac7_row1_col2, #T_f2ac7_row2_col2, #T_f2ac7_row3_col2, #T_f2ac7_row4_col2, #T_f2ac7_row5_col2, #T_f2ac7_row6_col2, #T_f2ac7_row7_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_f2ac7_row0_col3, #T_f2ac7_row1_col3, #T_f2ac7_row2_col3, #T_f2ac7_row3_col3, #T_f2ac7_row4_col3, #T_f2ac7_row5_col3, #T_f2ac7_row6_col3, #T_f2ac7_row7_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_f2ac7_row0_col4, #T_f2ac7_row1_col4, #T_f2ac7_row2_col4, #T_f2ac7_row3_col4, #T_f2ac7_row4_col4, #T_f2ac7_row5_col4, #T_f2ac7_row6_col4, #T_f2ac7_row7_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_f2ac7_row0_col5, #T_f2ac7_row1_col5, #T_f2ac7_row2_col5, #T_f2ac7_row3_col5, #T_f2ac7_row4_col5, #T_f2ac7_row5_col5, #T_f2ac7_row6_col5, #T_f2ac7_row7_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_f2ac7">
#   <caption><strong>Data Frame Summary</strong><br>_<br>Dimensions: 10,760 x 8<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_f2ac7_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_f2ac7_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_f2ac7_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_f2ac7_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_f2ac7_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_f2ac7_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f2ac7_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f2ac7_row0_col1" class="data row0 col1" ><strong>longitude</strong><br>[float64]</td>
#       <td id="T_f2ac7_row0_col2" class="data row0 col2" >Mean (sd) : -87.7 (0.1)<br>min < med < max:<br>-87.9 < -87.7 < -87.5<br>IQR (CV) : 0.1 (-1388.7)</td>
#       <td id="T_f2ac7_row0_col3" class="data row0 col3" >10,743 distinct values</td>
#       <td id="T_f2ac7_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_f2ac7_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f2ac7_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_f2ac7_row1_col1" class="data row1 col1" ><strong>latitude</strong><br>[float64]</td>
#       <td id="T_f2ac7_row1_col2" class="data row1 col2" >Mean (sd) : 41.9 (0.1)<br>min < med < max:<br>41.6 < 41.9 < 42.1<br>IQR (CV) : 0.2 (439.7)</td>
#       <td id="T_f2ac7_row1_col3" class="data row1 col3" >10,743 distinct values</td>
#       <td id="T_f2ac7_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_f2ac7_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f2ac7_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_f2ac7_row2_col1" class="data row2 col1" ><strong>systemstop</strong><br>[float64]</td>
#       <td id="T_f2ac7_row2_col2" class="data row2 col2" >Mean (sd) : 8560.9 (5234.7)<br>min < med < max:<br>1.0 < 8579.5 < 18625.0<br>IQR (CV) : 8314.8 (1.6)</td>
#       <td id="T_f2ac7_row2_col3" class="data row2 col3" >10,760 distinct values</td>
#       <td id="T_f2ac7_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_f2ac7_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f2ac7_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_f2ac7_row3_col1" class="data row3 col1" ><strong>street</strong><br>[object]</td>
#       <td id="T_f2ac7_row3_col2" class="data row3 col2" >1. PULASKI<br>2. HALSTED<br>3. KEDZIE<br>4. CICERO<br>5. WESTERN<br>6. CALIFORNIA<br>7. DAMEN<br>8. 63RD STREET<br>9. ASHLAND<br>10. STATE<br>11. other</td>
#       <td id="T_f2ac7_row3_col3" class="data row3 col3" >316 (2.9%)<br>302 (2.8%)<br>254 (2.4%)<br>252 (2.3%)<br>227 (2.1%)<br>226 (2.1%)<br>224 (2.1%)<br>196 (1.8%)<br>175 (1.6%)<br>171 (1.6%)<br>8,417 (78.2%)</td>
#       <td id="T_f2ac7_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_f2ac7_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f2ac7_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_f2ac7_row4_col1" class="data row4 col1" ><strong>cross_st</strong><br>[object]</td>
#       <td id="T_f2ac7_row4_col2" class="data row4 col2" >1. KEDZIE<br>2. ASHLAND<br>3. CALIFORNIA<br>4. DAMEN<br>5. OAKLEY<br>6. HALSTED<br>7. WESTERN<br>8. PULASKI<br>9. KOSTNER<br>10. WASHTENAW<br>11. other</td>
#       <td id="T_f2ac7_row4_col3" class="data row4 col3" >80 (0.7%)<br>79 (0.7%)<br>76 (0.7%)<br>67 (0.6%)<br>65 (0.6%)<br>65 (0.6%)<br>63 (0.6%)<br>62 (0.6%)<br>60 (0.6%)<br>59 (0.5%)<br>10,084 (93.7%)</td>
#       <td id="T_f2ac7_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_f2ac7_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f2ac7_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_f2ac7_row5_col1" class="data row5 col1" ><strong>city</strong><br>[object]</td>
#       <td id="T_f2ac7_row5_col2" class="data row5 col2" >1. CHICAGO<br>2. EVANSTON<br>3. SKOKIE<br>4. CICERO<br>5. OAK PARK<br>6. EVERGREEN PARK<br>7. NORRIDGE<br>8. BEDFORD PARK<br>9. HARWOOD HEIGHTS<br>10. LINCOLNWOOD<br>11. other</td>
#       <td id="T_f2ac7_row5_col3" class="data row5 col3" >9,917 (92.2%)<br>199 (1.8%)<br>120 (1.1%)<br>74 (0.7%)<br>73 (0.7%)<br>62 (0.6%)<br>49 (0.5%)<br>46 (0.4%)<br>38 (0.4%)<br>31 (0.3%)<br>151 (1.4%)</td>
#       <td id="T_f2ac7_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_f2ac7_row5_col5" class="data row5 col5" >1<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f2ac7_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_f2ac7_row6_col1" class="data row6 col1" ><strong>public_nam</strong><br>[object]</td>
#       <td id="T_f2ac7_row6_col2" class="data row6 col2" >1. Jefferson Park Transit Center<br>2. 95th Red Line Station<br>3. Midway Orange Line Station<br>4. 35th/Archer Orange Line Statio<br>5. 69th Red Line Station<br>6. Paulina & Howard Terminal<br>7. Kedzie Orange Line Station<br>8. Pershing & King Drive<br>9. 95th Street & King Drive<br>10. South Chicago & 71st Street/Co<br>11. other</td>
#       <td id="T_f2ac7_row6_col3" class="data row6 col3" >10 (0.1%)<br>10 (0.1%)<br>9 (0.1%)<br>7 (0.1%)<br>5 (0.0%)<br>5 (0.0%)<br>5 (0.0%)<br>4 (0.0%)<br>4 (0.0%)<br>4 (0.0%)<br>10,697 (99.4%)</td>
#       <td id="T_f2ac7_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_f2ac7_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f2ac7_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_f2ac7_row7_col1" class="data row7 col1" ><strong>location</strong><br>[object]</td>
#       <td id="T_f2ac7_row7_col2" class="data row7 col2" >1. POINT(-87.70670517000002 41.89<br>2. POINT(-87.74750923800002 41.95<br>3. POINT(-87.699355529 41.8953254<br>4. POINT(-87.65449964700002 41.89<br>5. POINT(-87.62946700100002 41.89<br>6. POINT(-87.77091308299998 41.91<br>7. POINT(-87.74053318900002 41.91<br>8. POINT(-87.66209989499998 41.89<br>9. POINT(-87.71729953699997 41.90<br>10. POINT(-87.6868442

# %% [markdown]
# ## Cleaning & Transformation

# %%
#Drop columns
bus_data_v2 = bus_data.drop(['dir','pos','routesstpg'],axis=1)

#Cast as a point 
bus_data_v2['location'] = bus_data_v2.apply(
    lambda row: f"POINT({row['longitude']} {row['latitude']})" 
    if pd.notnull(row['longitude']) and pd.notnull(row['latitude']) 
    else None,
    axis=1
)

bus_data_v2
# Out:
#        longitude   latitude  systemstop        street                cross_st  \
# 0     -87.747509  41.956892     15189.0        CICERO     BERTEAU (north leg)
# 1     -87.703980  41.805777      3082.0        KEDZIE  48TH PLACE (north leg)
# 2     -87.640475  41.943530      1157.0    LAKE SHORE                  ROSCOE
# 3     -87.585295  41.722579      7211.0  STONY ISLAND             95TH STREET
# 4     -87.743174  41.802234      8123.0        CICERO             50TH STREET
# ...          ...        ...         ...           ...                     ...
# 10755 -87.754441  42.026419      3550.0        OAKTON                 LINCOLN
# 10756 -87.743902  42.026198      3599.0        OAKTON                    KNOX
# 10757 -87.730601  42.026200      3605.0        OAKTON                  KARLOV
# 10758 -87.714694  42.026198      3612.0        OAKTON               3450 WEST
# 10759 -87.743702  42.026350      3546.0        OAKTON                    KNOX
#
#           city                  public_nam  \
# 0      CHICAGO            Cicero & Berteau
# 1      CHICAGO         Kedzie & 48th Place
# 2      CHICAGO         Lake Shore & Roscoe
# 3      CHICAGO  Stony Island & 95th Street
# 4      CHICAGO        Cicero & 50th Street
# ...        ...                         ...
# 10755   SKOKIE            Oakton & Lincoln
# 10756   SKOKIE               Oakton & Knox
# 10757   SKOKIE             Oakton & Karlov
# 10758   SKOKIE               3450 W Oakton
# 10759   SKOKIE               Oakton & Knox
#
#                                            location
# 0            POINT(-87.74750923800002 41.956892084)
# 1               POINT(-87.70398 41.805777001000024)
# 2      POINT(-87.64047498399998 41.943529618000014)
# 3      POINT(-87.58529500100002 41.722579000999986)
# 4            POINT(-87.743173716 41.80223378400001)
# ...                                             ...
# 10755   POINT(-87.75444054799999 42.02641861000001)
# 10756   POINT(-87.74390199999999 42.02619800000002)
# 10757   POINT(-87.73060099999998 42.02620000000002)
# 10758        POINT(-87.714694001 42.02619800000002)
# 10759  POINT(-87.74370155999998 42.026349547999985)
#
# [10760 rows x 8 columns]

# %%
bus_data_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10760 entries, 0 to 10759
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   longitude   10760 non-null  float64
#  1   latitude    10760 non-null  float64
#  2   systemstop  10760 non-null  float64
#  3   street      10760 non-null  object
#  4   cross_st    10760 non-null  object
#  5   city        10759 non-null  object
#  6   public_nam  10760 non-null  object
#  7   location    10760 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 672.6+ KB

# %% [markdown]
# # 2.5 Divvy Bike Data

# %%
divvy_stations
# Out:
#                                        id                station_name  \
# 0                     1859717767703464460    Kedzie Ave & Redfield Dr
# 1    a3a3dc37-a135-11e9-9cda-0a87ae2ba916    Fairbanks Ct & Grand Ave
# 2                     1861588043429399408  McCormick Blvd & Devon Ave
# 3                     2057127898206728832      Halsted St & Roscoe St
# 4    9e1fbaaa-e872-4505-ada6-5080e62bef77   Lincoln Park Conservatory
# ..                                    ...                         ...
# 995  a3a80a1e-a135-11e9-9cda-0a87ae2ba916      Clark St & Drummond Pl
# 996  a3a83ba1-a135-11e9-9cda-0a87ae2ba916       Wood St & Webster Ave
# 997  a3aa5ed1-a135-11e9-9cda-0a87ae2ba916   Damen Ave & Charleston St
# 998  87c01e57-8a00-430d-9eb3-2abe51e535dd       Vernon Ave & 107th St
# 999  c3f1be96-07c2-4c65-8a1d-f2203de88495        Halsted St & 78th St
#
#     short_name  total_docks  docks_in_service      status   latitude  \
# 0     CHI01795           15                15  In Service  41.765230
# 1     CHI00605           15                15  In Service  41.891847
# 2     CHI01881           11                11  In Service  41.997200
# 3     CHI00473           12                12  In Service  41.943670
# 4     CHI00626           31                31  In Service  41.923931
# ..         ...          ...               ...         ...        ...
# 995   CHI00385           23                23  In Service  41.931248
# 996   CHI00331           19                19  In Service  41.921057
# 997   CHI00403           11                11  In Service  41.920082
# 998   CHI00772           15                15  In Service  41.700121
# 999   CHI00857           15                15  In Service  41.752487
#
#      longitude location_type                 location_coordinates
# 0   -87.703160         Point                [-87.70316, 41.76523]
# 1   -87.620580         Point   [-87.620580196381, 41.89184737211]
# 2   -87.711050         Point                 [-87.71105, 41.9972]
# 3   -87.648950         Point                [-87.64895, 41.94367]
# 4   -87.635825         Point  [-87.635824531317, 41.923931311366]
# ..         ...           ...                                  ...
# 995 -87.644336         Point              [-87.644336, 41.931248]
# 996 -87.672797         Point  [-87.672797441483, 41.921056729928]
# 997 -87.677855         Point              [-87.677855, 41.920082]
# 998 -87.612260         Point  [-87.612259984016, 41.700121379239]
# 999 -87.643902         Point   [-87.643902157488, 41.75248701249]
#
# [1000 rows x 10 columns]

# %%
import ast
# Drop 'short_name' column
divvy_stations = divvy_stations.drop(columns=['short_name'])

# Keep only rows where status is 'In Service'
divvy_stations = divvy_stations[divvy_stations['status'] == 'In Service']

# Create WKT 'geometry' column using existing float columns
divvy_stations['geometry'] = divvy_stations.apply(
    lambda row: f"POINT({row['longitude']} {row['latitude']})"
    if pd.notnull(row['longitude']) and pd.notnull(row['latitude']) else None,
    axis=1
)
divvy_stations
# Out:
#                                        id                station_name  \
# 0                     1859717767703464460    Kedzie Ave & Redfield Dr
# 1    a3a3dc37-a135-11e9-9cda-0a87ae2ba916    Fairbanks Ct & Grand Ave
# 2                     1861588043429399408  McCormick Blvd & Devon Ave
# 3                     2057127898206728832      Halsted St & Roscoe St
# 4    9e1fbaaa-e872-4505-ada6-5080e62bef77   Lincoln Park Conservatory
# ..                                    ...                         ...
# 995  a3a80a1e-a135-11e9-9cda-0a87ae2ba916      Clark St & Drummond Pl
# 996  a3a83ba1-a135-11e9-9cda-0a87ae2ba916       Wood St & Webster Ave
# 997  a3aa5ed1-a135-11e9-9cda-0a87ae2ba916   Damen Ave & Charleston St
# 998  87c01e57-8a00-430d-9eb3-2abe51e535dd       Vernon Ave & 107th St
# 999  c3f1be96-07c2-4c65-8a1d-f2203de88495        Halsted St & 78th St
#
#      total_docks  docks_in_service      status   latitude  longitude  \
# 0             15                15  In Service  41.765230 -87.703160
# 1             15                15  In Service  41.891847 -87.620580
# 2             11                11  In Service  41.997200 -87.711050
# 3             12                12  In Service  41.943670 -87.648950
# 4             31                31  In Service  41.923931 -87.635825
# ..           ...               ...         ...        ...        ...
# 995           23                23  In Service  41.931248 -87.644336
# 996           19                19  In Service  41.921057 -87.672797
# 997           11                11  In Service  41.920082 -87.677855
# 998           15                15  In Service  41.700121 -87.612260
# 999           15                15  In Service  41.752487 -87.643902
#
#     location_type                 location_coordinates  \
# 0           Point                [-87.70316, 41.76523]
# 1           Point   [-87.620580196381, 41.89184737211]
# 2           Point                 [-87.71105, 41.9972]
# 3           Point                [-87.64895, 41.94367]
# 4           Point  [-87.635824531317, 41.923931311366]
# ..            ...                                  ...
# 995         Point              [-87.644336, 41.931248]
# 996         Point  [-87.672797441483, 41.921056729928]
# 997         Point              [-87.677855, 41.920082]
# 998         Point  [-87.612259984016, 41.700121379239]
# 999         Point   [-87.643902157488, 41.75248701249]
#
#                                 geometry
# 0              POINT(-87.70316 41.76523)
# 1    POINT(-87.6205801964 41.8918473721)
# 2               POINT(-87.71105 41.9972)
# 3              POINT(-87.64895 41.94367)
# 4    POINT(-87.6358245313 41.9239313114)
# ..                                   ...
# 995          POINT(-87.644336 41.931248)
# 996  POINT(-87.6727974415 41.9210567299)
# 997          POINT(-87.677855 41.920082)
# 998   POINT(-87.612259984 41.7001213792)
# 999  POINT(-87.6439021575 41.7524870125)
#
# [998 rows x 10 columns]

# %%
from summarytools import dfSummary
dfSummary(divvy_stations)
# Out:
# <style type="text/css">
# #T_2b769 thead>tr>th {
#   text-align: left;
# }
# #T_2b769_row0_col0, #T_2b769_row1_col0, #T_2b769_row2_col0, #T_2b769_row3_col0, #T_2b769_row4_col0, #T_2b769_row5_col0, #T_2b769_row6_col0, #T_2b769_row7_col0, #T_2b769_row8_col0, #T_2b769_row9_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_2b769_row0_col1, #T_2b769_row1_col1, #T_2b769_row2_col1, #T_2b769_row3_col1, #T_2b769_row4_col1, #T_2b769_row5_col1, #T_2b769_row6_col1, #T_2b769_row7_col1, #T_2b769_row8_col1, #T_2b769_row9_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_2b769_row0_col2, #T_2b769_row1_col2, #T_2b769_row2_col2, #T_2b769_row3_col2, #T_2b769_row4_col2, #T_2b769_row5_col2, #T_2b769_row6_col2, #T_2b769_row7_col2, #T_2b769_row8_col2, #T_2b769_row9_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_2b769_row0_col3, #T_2b769_row1_col3, #T_2b769_row2_col3, #T_2b769_row3_col3, #T_2b769_row4_col3, #T_2b769_row5_col3, #T_2b769_row6_col3, #T_2b769_row7_col3, #T_2b769_row8_col3, #T_2b769_row9_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_2b769_row0_col4, #T_2b769_row1_col4, #T_2b769_row2_col4, #T_2b769_row3_col4, #T_2b769_row4_col4, #T_2b769_row5_col4, #T_2b769_row6_col4, #T_2b769_row7_col4, #T_2b769_row8_col4, #T_2b769_row9_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_2b769_row0_col5, #T_2b769_row1_col5, #T_2b769_row2_col5, #T_2b769_row3_col5, #T_2b769_row4_col5, #T_2b769_row5_col5, #T_2b769_row6_col5, #T_2b769_row7_col5, #T_2b769_row8_col5, #T_2b769_row9_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_2b769">
#   <caption><strong>Data Frame Summary</strong><br>_<br>Dimensions: 998 x 10<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_2b769_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_2b769_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_2b769_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_2b769_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_2b769_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_2b769_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2b769_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_2b769_row0_col1" class="data row0 col1" ><strong>id</strong><br>[object]</td>
#       <td id="T_2b769_row0_col2" class="data row0 col2" >1. 1859717767703464460<br>2. 1989626448622643348<br>3. 1872723419889143870<br>4. a3ab8bee-a135-11e9-9cda-0a87ae<br>5. a3af624c-a135-11e9-9cda-0a87ae<br>6. a3af8b51-a135-11e9-9cda-0a87ae<br>7. a3ad47f8-a135-11e9-9cda-0a87ae<br>8. 2072426969175128454<br>9. a3b241df-a135-11e9-9cda-0a87ae<br>10. a3a945c0-a135-11e9-9cda-0a87ae<br>11. other</td>
#       <td id="T_2b769_row0_col3" class="data row0 col3" >1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>988 (99.0%)</td>
#       <td id="T_2b769_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_2b769_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_2b769_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_2b769_row1_col1" class="data row1 col1" ><strong>station_name</strong><br>[object]</td>
#       <td id="T_2b769_row1_col2" class="data row1 col2" >1. Indiana Ave & 133rd St<br>2. Western Ave & Lake St<br>3. Burling St & Diversey Pkwy<br>4. Major Taylor Trail & 124th St<br>5. Columbus Ave & 83rd Pl<br>6. Racine Ave & Wrightwood Ave<br>7. Budlong Woods Library<br>8. Kedzie Ave & Leland Ave<br>9. Princeton Ave & 47th St<br>10. Ave L & 114th<br>11. other</td>
#       <td id="T_2b769_row1_col3" class="data row1 col3" >2 (0.2%)<br>2 (0.2%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>986 (98.8%)</td>
#       <td id="T_2b769_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_2b769_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_2b769_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_2b769_row2_col1" class="data row2 col1" ><strong>total_docks</strong><br>[int64]</td>
#       <td id="T_2b769_row2_col2" class="data row2 col2" >Mean (sd) : 16.6 (10.8)<br>min < med < max:<br>1.0 < 15.0 < 120.0<br>IQR (CV) : 4.0 (1.5)</td>
#       <td id="T_2b769_row2_col3" class="data row2 col3" >32 distinct values</td>
#       <td id="T_2b769_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_2b769_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_2b769_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_2b769_row3_col1" class="data row3 col1" ><strong>docks_in_service</strong><br>[int64]</td>
#       <td id="T_2b769_row3_col2" class="data row3 col2" >Mean (sd) : 16.6 (10.8)<br>min < med < max:<br>1.0 < 15.0 < 120.0<br>IQR (CV) : 4.0 (1.5)</td>
#       <td id="T_2b769_row3_col3" class="data row3 col3" >32 distinct values</td>
#       <td id="T_2b769_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_2b769_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_2b769_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_2b769_row4_col1" class="data row4 col1" ><strong>status</strong><br>[object]</td>
#       <td id="T_2b769_row4_col2" class="data row4 col2" >1. In Service</td>
#       <td id="T_2b769_row4_col3" class="data row4 col3" >998 (100.0%)</td>
#       <td id="T_2b769_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_2b769_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_2b769_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_2b769_row5_col1" class="data row5 col1" ><strong>latitude</strong><br>[float64]</td>
#       <td id="T_2b769_row5_col2" class="data row5 col2" >Mean (sd) : 41.9 (0.1)<br>min < med < max:<br>41.6 < 41.9 < 42.1<br>IQR (CV) : 0.1 (477.3)</td>
#       <td id="T_2b769_row5_col3" class="data row5 col3" >996 distinct values</td>
#       <td id="T_2b769_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_2b769_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_2b769_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_2b769_row6_col1" class="data row6 col1" ><strong>longitude</strong><br>[float64]</td>
#       <td id="T_2b769_row6_col2" class="data row6 col2" >Mean (sd) : -87.7 (0.1)<br>min < med < max:<br>-87.8 < -87.7 < -87.5<br>IQR (CV) : 0.1 (-1610.8)</td>
#       <td id="T_2b769_row6_col3" class="data row6 col3" >993 distinct values</td>
#       <td id="T_2b769_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_2b769_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_2b769_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_2b769_row7_col1" class="data row7 col1" ><strong>location_type</strong><br>[object]</td>
#       <td id="T_2b769_row7_col2" class="data row7 col2" >1. Point</td>
#       <td id="T_2b769_row7_col3" class="data row7 col3" >998 (100.0%)</td>
#       <td id="T_2b769_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_2b769_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_2b769_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_2b769_row8_col1" class="data row8 col1" ><strong>location_coordinates</strong><br>[object]</td>
#       <td id="T_2b769_row8_col2

# %% [markdown]
# # 2.6 Yearly average

# %%
yearly_average.head()
# Out:
#    latitude  longitude  yearly_average_foot_traffic
# 0   41.9115   -87.7656                           50
# 1   41.9729   -87.7479                           51
# 2   41.9978   -87.8055                           51
# 3   41.6746   -87.6274                           55
# 4   41.8322   -87.6218                           55

# %%
dfSummary(yearly_average)
# Out:
# <style type="text/css">
# #T_e04a0 thead>tr>th {
#   text-align: left;
# }
# #T_e04a0_row0_col0, #T_e04a0_row1_col0, #T_e04a0_row2_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_e04a0_row0_col1, #T_e04a0_row1_col1, #T_e04a0_row2_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_e04a0_row0_col2, #T_e04a0_row1_col2, #T_e04a0_row2_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_e04a0_row0_col3, #T_e04a0_row1_col3, #T_e04a0_row2_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_e04a0_row0_col4, #T_e04a0_row1_col4, #T_e04a0_row2_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_e04a0_row0_col5, #T_e04a0_row1_col5, #T_e04a0_row2_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_e04a0">
#   <caption><strong>Data Frame Summary</strong><br>yearly_average<br>Dimensions: 1,276 x 3<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_e04a0_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_e04a0_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_e04a0_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_e04a0_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_e04a0_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_e04a0_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e04a0_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e04a0_row0_col1" class="data row0 col1" ><strong>latitude</strong><br>[float64]</td>
#       <td id="T_e04a0_row0_col2" class="data row0 col2" >Mean (sd) : 41.8 (0.1)<br>min < med < max:<br>41.7 < 41.9 < 42.0<br>IQR (CV) : 0.1 (498.2)</td>
#       <td id="T_e04a0_row0_col3" class="data row0 col3" >968 distinct values</td>
#       <td id="T_e04a0_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_e04a0_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e04a0_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e04a0_row1_col1" class="data row1 col1" ><strong>longitude</strong><br>[float64]</td>
#       <td id="T_e04a0_row1_col2" class="data row1 col2" >Mean (sd) : -87.7 (0.1)<br>min < med < max:<br>-87.9 < -87.7 < -87.5<br>IQR (CV) : 0.1 (-1438.2)</td>
#       <td id="T_e04a0_row1_col3" class="data row1 col3" >930 distinct values</td>
#       <td id="T_e04a0_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_e04a0_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e04a0_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e04a0_row2_col1" class="data row2 col1" ><strong>yearly_average_foot_traffic</strong><br>[int64]</td>
#       <td id="T_e04a0_row2_col2" class="data row2 col2" >Mean (sd) : 1220.4 (1616.7)<br>min < med < max:<br>50.0 < 709.0 < 11925.0<br>IQR (CV) : 1057.2 (0.8)</td>
#       <td id="T_e04a0_row2_col3" class="data row2 col3" >914 distinct values</td>
#       <td id="T_e04a0_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_e04a0_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>
